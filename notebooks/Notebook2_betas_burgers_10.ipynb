# %% [markdown]
# # ∂-FNO Theory Validation: Burgers Equation (Smooth, ν=0.1)
#
# ## Supplementary Material for Figure 2
#
# > **Note:** This notebook is provided for illustration purposes only.
# > Full code and reproducible experiments will be available on GitHub upon acceptance.
# >
# > Results may vary with hardware configurations.
# > **Tip:** Lower batch sizes generally yield better metrics but require longer training time.
#
# ---
#
# ### Experimental Setup
#
# | Setting | Value |
# |---------|-------|
# | Model | FNO (width 64, 4 layers) |
# | Dataset | Burgers (ν=0.1, smooth regime) |
# | Learnable | Single β (initialized at 1.5) |
# | Seeds | 3 |
# | Default | n=1000, σ=0.01, k=16 |
#
# ### Experiments
#
# | Panel | Sweep Variable | Values | Fixed Parameters |
# |-------|---------------|--------|------------------|
# | **Left** | Noise σ | {0.0, 0.01, 0.02, 0.05, 0.10} | n=1000, k=16 |
# | **Center** | Samples n | {125, 250, 500, 1000} | σ=0.01, k=16 |
# | **Right** | Modes k | {16, 32, 64, 128} | n=1000, σ=0.01 |
#
# ### Theoretical Predictions (Theorem 5.4)
# - σ ↑ ⇒ β* ↓ (more noise → lower optimal order)
# - n ↑ ⇒ β* ↑ (more data → higher optimal order)
# - k ↑ ⇒ β* ↓ (more capacity → lower optimal order)

# %%
# @title Cell 1: Imports and Setup
import os
import sys
import json
import time
import glob
import logging
from datetime import datetime
from dataclasses import dataclass, field, asdict
from typing import Dict, List, Tuple, Optional, Any
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pandas as pd
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')

# ═══════════════════════════════════════════════════════════════════
#                         LOGGING SETUP
# ═══════════════════════════════════════════════════════════════════
def setup_logger(name: str, log_file: str = None, level=logging.INFO):
    """Setup logger with console and optional file output."""
    logger = logging.getLogger(name)
    logger.setLevel(level)
    logger.handlers = []  # Clear existing handlers

    # Console handler
    console = logging.StreamHandler()
    console.setLevel(level)
    fmt = logging.Formatter('%(asctime)s | %(levelname)s | %(message)s', datefmt='%H:%M:%S')
    console.setFormatter(fmt)
    logger.addHandler(console)

    # File handler (optional)
    if log_file:
        os.makedirs(os.path.dirname(log_file), exist_ok=True)
        fh = logging.FileHandler(log_file)
        fh.setLevel(level)
        fh.setFormatter(fmt)
        logger.addHandler(fh)

    return logger

# Create directories first
os.makedirs('./results', exist_ok=True)
os.makedirs('./data', exist_ok=True)

# Create main logger
log = setup_logger('DELFNO', log_file='./results/burgers_r10.log')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.dpi'] = 150
plt.rcParams['font.size'] = 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
log.info(f"Device: {device}")
if torch.cuda.is_available():
    log.info(f"GPU: {torch.cuda.get_device_name()}")
    log.info(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# 17:01:53 | INFO | Device: cuda
# INFO:DELFNO:Device: cuda
# 17:01:53 | INFO | GPU: NVIDIA A100-SXM4-40GB
# INFO:DELFNO:GPU: NVIDIA A100-SXM4-40GB
# 17:01:53 | INFO | Memory: 42.5 GB
# INFO:DELFNO:Memory: 42.5 GB

# %%
# @title Cell 2: Configuration
# ═══════════════════════════════════════════════════════════════════
#                    CONFIGURATION - BURGERS R=10
# ═══════════════════════════════════════════════════════════════════

@dataclass
class Config:
    """Master configuration aligned with neurops.py and DELFNO_BURGERS_SPEC.md"""

    # ==================== DATASET ====================
    dataset: str = 'r10'         # Burgers R=10 (smooth solutions)
    reynolds: int = 10

    # ==================== MODEL ARCHITECTURE (neurops.py aligned) ====================
    modes: int = 16              # Fourier modes to keep
    n_hidden: int = 64           # Hidden channel width (was 'width')
    n_layers: int = 4            # Number of FNO blocks (fixed as in original)

    # ==================== DEL-FNO SPECIFIC (from SPEC) ====================
    nb_beta: int = 2             # Number of derivative orders
    K: int = 16                  # Grünwald-Letnikov kernel size
    init_betas: List[float] = field(default_factory=lambda: [1.0, 2.0])
    stencil_only: bool = True    # No h^β normalization
    include_original: bool = True  # Include original signal in augmentation

    # ==================== TRAINING (from SPEC) ====================
    epochs: int = 500           # Training epochs (increased from 1000)
    batch_size: int = 8          # Batch size (reduced from 256)
    lr: float = 1e-3             # Learning rate for backbone
    lr_beta: float = 1e-2        # Learning rate for β (10× backbone)
    weight_decay: float = 1e-5   # Weight decay for backbone
    wd_beta: float = 0.0         # No weight decay for β
    grad_clip: float = 1.0       # Gradient clipping

    # ==================== SCHEDULER ====================
    scheduler: str = 'onecycle'  # OneCycleLR (from SPEC)

    # ==================== DATA ====================
    n_train: int = 1000          # Training samples
    n_test: int = 200            # Test samples
    resolution: int = 1024       # Spatial resolution

    # ==================== EXPERIMENT SETTINGS ====================
    seeds: List[int] = field(default_factory=lambda: [42, 108, 888])  # 3 seeds
    models: List[str] = field(default_factory=lambda: ['FNO', 'DEL-FNO'])

    # ==================== EXPERIMENT 1: NOISE ====================
    noise_levels: List[float] = field(default_factory=lambda: [0.0, 0.01, 0.02, 0.05, 0.10])

    # ==================== EXPERIMENT 2: SAMPLE SIZE ====================
    sample_sizes: List[int] = field(default_factory=lambda: [125, 250, 500, 1000])

    # ==================== EXPERIMENT 3: MODES (changed from batch_size) ====================
    modes_list: List[int] = field(default_factory=lambda: [16, 32, 64, 128])

    # ==================== PATHS ====================
    data_dir: str = './data'
    results_dir: str = './results'

    # ==================== LOGGING ====================
    verbose: bool = True
    log_interval: int = 100      # Log every N epochs
    save_checkpoints: bool = False

    def __post_init__(self):
        os.makedirs(self.results_dir, exist_ok=True)
        os.makedirs(self.data_dir, exist_ok=True)
        if len(self.init_betas) != self.nb_beta:
            self.init_betas = [1.0 * (i + 1) for i in range(self.nb_beta)]

# Create config instance
cfg = Config()

# Log configuration
log.info("="*60)
log.info("CONFIGURATION - BURGERS R=10")
log.info("="*60)
for k, v in asdict(cfg).items():
    log.info(f"  {k}: {v}")
log.info("="*60)
# Out:
# 17:01:53 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 17:01:53 | INFO | CONFIGURATION - BURGERS R=10
# INFO:DELFNO:CONFIGURATION - BURGERS R=10
# 17:01:53 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 17:01:53 | INFO |   dataset: r10
# INFO:DELFNO:  dataset: r10
# 17:01:53 | INFO |   reynolds: 10
# INFO:DELFNO:  reynolds: 10
# 17:01:53 | INFO |   modes: 16
# INFO:DELFNO:  modes: 16
# 17:01:53 | INFO |   n_hidden: 64
# INFO:DELFNO:  n_hidden: 64
# 17:01:53 | INFO |   n_layers: 4
# INFO:DELFNO:  n_layers: 4
# 17:01:53 | INFO |   nb_beta: 2
# INFO:DELFNO:  nb_beta: 2
# 17:01:53 | INFO |   K: 16
# INFO:DELFNO:  K: 16
# 17:01:53 | INFO |   init_betas: [1.0, 2.0]
# INFO:DELFNO:  init_betas: [1.0, 2.0]
# 17:01:53 | INFO |   stencil_only: True
# INFO:DELFNO:  stencil_only: True
# 17:01:53 | INFO |   include_original: True
# INFO:DELFNO:  include_original: True
# 17:01:53 | INFO |   epochs: 500
# INFO:DELFNO:  epochs: 500
# 17:01:53 | INFO |   batch_size: 8
# INFO:DELFNO:  batch_size: 8
# 17:01:53 | INFO |   lr: 0.001
# INFO:DELFNO:  lr: 0.001
# 17:01:53 | INFO |   lr_beta: 0.01
# INFO:DELFNO:  lr_beta: 0.01
# 17:01:53 | INFO |   weight_decay: 1e-05
# INFO:DELFNO:  weight_decay: 1e-05
# 17:01:53 | INFO |   wd_beta: 0.0
# INFO:DELFNO:  wd_beta: 0.0
# 17:01:53 | INFO |   grad_clip: 1.0
# INFO:DELFNO:  grad_clip: 1.0
# 17:01:53 | INFO |   scheduler: onecycle
# INFO:DELFNO:  scheduler: onecycle
# 17:01:53 | INFO |   n_train: 1000
# INFO:DELFNO:  n_train: 1000
# 17:01:53 | INFO |   n_test: 200
# INFO:DELFNO:  n_test: 200
# 17:01:53 | INFO |   resolution: 1024
# INFO:DELFNO:  resolution: 1024
# 17:01:53 | INFO |   seeds: [42, 108, 888]
# INFO:DELFNO:  seeds: [42, 108, 888]
# 17:01:53 | INFO |   models: ['FNO', 'DEL-FNO']
# INFO:DELFNO:  models: ['FNO', 'DEL-FNO']
# 17:01:53 | INFO |   noise_levels: [0.0, 0.01, 0.02, 0.05, 0.1]
# INFO:DELFNO:  noise_levels: [0.0, 0.01, 0.02, 0.05, 0.1]
# 17:01:53 | INFO |   sample_sizes: [125, 250, 500, 1000]
# INFO:DELFNO:  sample_sizes: [125, 250, 500, 1000]
# 17:01:53 | INFO |   modes_list: [16, 32, 64, 128]
# INFO:DELFNO:  modes_list: [16, 32, 64, 128]
# 17:01:53 | INFO |   data_dir: ./data
# INFO:DELFNO:  data_dir: ./data
# 17:01:53 | INFO |   results_dir: ./results
# INFO:DELFNO:  results_dir: ./results
# 17:01:53 | INFO |   verbose: True
# INFO:DELFNO:  verbose: True
# 17:01:53 | INFO |   log_interval: 100
# INFO:DELFNO:  log_interval: 100
# 17:01:53 | INFO |   save_checkpoints: False
# INFO:DELFNO:  save_checkpoints: False
# 17:01:53 | INFO | ============================================================
# INFO:DELFNO:============================================================

# %%
# @title Cell 4: Data Loading
# ═══════════════════════════════════════════════════════════════════
#                         DATA LOADING
# ═══════════════════════════════════════════════════════════════════

def load_burgers_data(cfg: Config) -> Dict[str, torch.Tensor]:
    """
    Load Burgers R=10 data following canonical FNO MatReader logic.

    Key insight from FNO utilities3.py:
    - scipy.io.loadmat (old .mat): NO transpose
    - h5py (HDF5/MATLAB v7.3): REVERSE all axes (Fortran order)
    """
    data_dir = cfg.data_dir
    reynolds = cfg.reynolds

    GDRIVE_IDS = {
        10: '1vFQHJetdoeU5w4x-cZBoHYvP-MWVtIK9',
        1000: '1G5sQPT4d5gT9dLP7pKBS8sfgKmSM1bVY',
    }
    MIN_SIZES = {10: 50_000_000, 1000: 100_000_000}

    # Find file
    patterns = [f'{data_dir}/burgers_r10.mat', f'{data_dir}/burgers_data_R10.mat',
                f'{data_dir}/burgers*r10*.mat', f'{data_dir}/Burgers*10*.mat']

    filepath = None
    for p in patterns:
        if '*' in p:
            for f in glob.glob(p):
                if os.path.getsize(f) >= MIN_SIZES.get(reynolds, 1e7):
                    filepath = f
                    break
        elif os.path.exists(p) and os.path.getsize(p) >= MIN_SIZES.get(reynolds, 1e7):
            filepath = p
        if filepath:
            break

    if not filepath:
        import gdown
        filepath = f'{data_dir}/burgers_r{reynolds}.mat'
        log.info(f"Downloading Burgers R={reynolds}...")
        gdown.download(f'https://drive.google.com/uc?id={GDRIVE_IDS[reynolds]}', filepath, quiet=False)

    log.info(f"Loading: {filepath} ({os.path.getsize(filepath)/1e6:.1f}MB)")

    a, u = None, None

    # Try scipy first (older .mat format)
    try:
        import scipy.io
        mat = scipy.io.loadmat(filepath)
        keys = [k for k in mat.keys() if not k.startswith('_')]
        log.info(f"  scipy keys: {keys}")

        if 'a' in mat:
            a, u = mat['a'].astype(np.float32), mat['u'].astype(np.float32)
        elif 'input' in mat:
            a, u = mat['input'].astype(np.float32), mat['output'].astype(np.float32)
        else:
            raise KeyError(f"Unknown keys: {keys}")

    except Exception as e:
        log.info(f"  scipy failed: {e}, trying h5py...")
        import h5py
        with h5py.File(filepath, 'r') as f:
            keys = list(f.keys())
            log.info(f"  h5py keys: {keys}")

            if 'input' in keys:
                a = np.array(f['input']).astype(np.float32)
                u = np.array(f['output']).astype(np.float32)
            elif 'a' in keys:
                a = np.array(f['a']).astype(np.float32)
                u = np.array(f['u']).astype(np.float32)
            else:
                raise KeyError(f"Unknown keys: {keys}")

            # h5py: REVERSE all axes (canonical FNO approach)
            a = np.transpose(a, axes=range(len(a.shape)-1, -1, -1))
            u = np.transpose(u, axes=range(len(u.shape)-1, -1, -1))

    # Handle 3D output (N, T, X) -> take final timestep
    if u.ndim == 3:
        log.info(f"  3D output {u.shape}, taking last timestep")
        if u.shape[1] < u.shape[2]:
            u = u[:, -1, :]
        else:
            u = u[:, :, -1]

    log.info(f"  Shapes after loading: a={a.shape}, u={u.shape}")

    # Subsample to target resolution
    N_grid = a.shape[-1]
    if cfg.resolution < N_grid:
        sub = N_grid // cfg.resolution
        a, u = a[:, ::sub][:, :cfg.resolution], u[:, ::sub][:, :cfg.resolution]

    a, u = torch.from_numpy(a), torch.from_numpy(u)
    log.info(f"  Final shapes: a={a.shape}, u={u.shape}")

    return {'a': a, 'u': u}


def prepare_data_splits(data: Dict, cfg: Config,
                        n_train: int = None, noise_level: float = 0.0,
                        seed: int = 0) -> Dict[str, torch.Tensor]:
    """
    Prepare train/test splits with optional noise and subsampling.
    """
    torch.manual_seed(seed)
    np.random.seed(seed)

    a, u = data['a'].clone(), data['u'].clone()

    if n_train is None:
        n_train = cfg.n_train
    n_test = cfg.n_test

    n_total = a.shape[0]
    if n_train + n_test > n_total:
        n_train = min(n_train, n_total - n_test)

    a_train, u_train = a[:n_train].clone(), u[:n_train].clone()
    a_test, u_test = a[n_total - n_test:].clone(), u[n_total - n_test:].clone()

    # Add noise to training inputs only (relative to std)
    if noise_level > 0:
        noise_std = noise_level * a_train.std()
        noise = torch.randn_like(a_train) * noise_std
        a_train = a_train + noise
        log.debug(f"  Added noise: level={noise_level}, std={noise_std:.6f}")

    return {
        'a_train': a_train.to(device),
        'u_train': u_train.to(device),
        'a_test': a_test.to(device),
        'u_test': u_test.to(device),
        'n_train': n_train,
        'noise_level': noise_level,
    }

# %%
# @title Cell 5: Model Definitions - FNO (aligned with neurops.py)
# ═══════════════════════════════════════════════════════════════════
#                    FNO MODEL (neurops.py aligned)
# ═══════════════════════════════════════════════════════════════════

class MLP(nn.Module):
    """Multi-Layer Perceptron with optional residual connections (from neurops.py)"""
    def __init__(self, n_input, n_hidden, n_output, n_layers=1, act='gelu', res=True):
        super().__init__()
        ACTIVATION = {'gelu': nn.GELU, 'relu': nn.ReLU, 'tanh': nn.Tanh, 'silu': nn.SiLU}
        act_fn = ACTIVATION.get(act, nn.GELU)
        self.n_layers = n_layers
        self.res = res
        # Input projection: n_input -> n_hidden with activation
        self.linear_pre = nn.Sequential(nn.Linear(n_input, n_hidden), act_fn())
        # Output projection: n_hidden -> n_output (no activation)
        self.linear_post = nn.Linear(n_hidden, n_output)
        # Hidden layers with activation
        self.linears = nn.ModuleList([
            nn.Sequential(nn.Linear(n_hidden, n_hidden), act_fn()) for _ in range(n_layers)])

    def forward(self, x):
        x = self.linear_pre(x)
        for i in range(self.n_layers):
            x = self.linears[i](x) + x if self.res else self.linears[i](x)
        return self.linear_post(x)


class SpectralConv1d(nn.Module):
    """1D Fourier Spectral Convolution (neurops.py aligned - NO normalization)"""
    def __init__(self, in_ch, out_ch, modes):
        super().__init__()
        self.modes = modes
        scale = 1 / (in_ch * out_ch)
        # IMPORTANT: torch.rand (uniform) not torch.randn (normal) - matches neurops.py
        self.weights = nn.Parameter(scale * torch.rand(in_ch, out_ch, modes, dtype=torch.cfloat))

    def forward(self, x):
        B = x.shape[0]
        # NO norm='ortho' - matches neurops.py
        x_ft = torch.fft.rfft(x)
        out_ft = torch.zeros(B, self.weights.shape[1], x.size(-1)//2+1, device=x.device, dtype=torch.cfloat)
        out_ft[:, :, :self.modes] = torch.einsum("bix,iox->box", x_ft[:, :, :self.modes], self.weights)
        return torch.fft.irfft(out_ft, n=x.size(-1))


class FNO1d(nn.Module):
    """
    Fourier Neural Operator for 1D problems.
    Architecture aligned with neurops.py:
    - MLP preprocess with 2× hidden expansion
    - 4 FNO blocks: GELU on first 3, NO activation on last
    - FFT padding for efficiency
    - NO InstanceNorm
    """
    def __init__(self, space_dim: int = 1, fun_dim: int = 1, out_dim: int = 1,
                 n_hidden: int = 64, n_layers: int = 4, modes: int = 16):
        super().__init__()
        self.__name__ = 'FNO'
        self.space_dim = space_dim
        self.fun_dim = fun_dim
        self.out_dim = out_dim
        self.n_hidden = n_hidden
        self.n_layers = n_layers
        self.modes = modes

        # ═══ Preprocessing (neurops.py: MLP with 2× hidden expansion) ═══
        # Input order: (x_coords, function) - matches neurops.py line 820
        self.preprocess = MLP(space_dim + fun_dim, n_hidden * 2, n_hidden, n_layers=0, res=False, act='gelu')

        # ═══ FNO layers (fixed 4 blocks as in original) ═══
        self.conv0 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv1 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv2 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv3 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.w0 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w1 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w2 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w3 = nn.Conv1d(n_hidden, n_hidden, 1)

        # ═══ Output projection ═══
        self.fc1 = nn.Linear(n_hidden, n_hidden)
        self.fc2 = nn.Linear(n_hidden, out_dim)

    def forward(self, a: torch.Tensor) -> torch.Tensor:
        # Input: (B, N) -> add grid coordinates
        B, N = a.shape

        # Grid coordinates (x)
        x_grid = torch.linspace(0, 1, N, device=a.device).unsqueeze(0).expand(B, -1).unsqueeze(-1)

        # Concatenate: (x_coords, function) - matches neurops.py order
        x = torch.cat([x_grid, a.unsqueeze(-1)], dim=-1)  # (B, N, 2) = (B, N, [x, a])

        # Preprocess: (B, N, 2) -> (B, N, n_hidden)
        fx = self.preprocess(x)

        # Reshape for conv: (B, N, C) -> (B, C, N)
        x = fx.permute(0, 2, 1)

        # ═══ FFT Padding for efficiency (16-aligned) ═══
        padding = (16 - N % 16) % 16
        if padding > 0:
            x = F.pad(x, (0, padding))

        # ═══ 4 FNO blocks (VERIFIED: gelu after first 3, NOT after last) ═══
        x = F.gelu(self.conv0(x) + self.w0(x))  # Block 0: activation
        x = F.gelu(self.conv1(x) + self.w1(x))  # Block 1: activation
        x = F.gelu(self.conv2(x) + self.w2(x))  # Block 2: activation
        x = self.conv3(x) + self.w3(x)          # Block 3: NO activation

        # ═══ Remove padding ═══
        if padding > 0:
            x = x[..., :N]

        # Output projection: (B, C, N) -> (B, N, C) -> (B, N, 1)
        x = x.permute(0, 2, 1)
        x = self.fc2(F.gelu(self.fc1(x)))

        return x.squeeze(-1)  # (B, N)

# %%
# @title Cell 6: Model Definitions - DEL-FNO (from SPEC)
# ═══════════════════════════════════════════════════════════════════
#                    DEL-FNO MODEL (from SPEC)
# ═══════════════════════════════════════════════════════════════════

def gl_weights(beta: torch.Tensor, K: int) -> torch.Tensor:
    """
    Grünwald-Letnikov weights for fractional derivative.

    w_0 = 1
    w_k = w_{k-1} * (k - 1 - β) / k

    AUTOGRAD-SAFE: No inplace operations.
    """
    if beta.dim() == 0:
        beta = beta.unsqueeze(0)

    n_orders = beta.shape[0]
    weights_list = [torch.ones(n_orders, device=beta.device, dtype=beta.dtype)]

    for k in range(1, K):
        # w_k = w_{k-1} * (k - 1 - β) / k
        factor = (k - 1 - beta) / k
        new_weight = weights_list[-1] * factor
        weights_list.append(new_weight)

    weights = torch.stack(weights_list, dim=1)  # (n_orders, K)
    return weights


class FracDerivBank(nn.Module):
    """
    Fractional Derivative Bank (from SPEC).

    Key features:
    - β = exp(γ) parameterization (ensures β > 0)
    - scale = relu(scale_) parameterization
    - Centered GL scheme: 0.5 * (backward + cos(πβ) * forward)
    - stencil_only=True (no h^β normalization)
    """
    def __init__(self, nb_beta: int, K: int, init_betas: List[float],
                 stencil_only: bool = True, include_original: bool = True):
        super().__init__()
        self.nb_beta = nb_beta
        self.K = K
        self.stencil_only = stencil_only
        self.include_original = include_original

        # β = exp(γ) parameterization (SPEC: ensures β > 0 without clamping)
        init_gamma = torch.log(torch.tensor(init_betas, dtype=torch.float32))
        self.gamma = nn.Parameter(init_gamma)

        # scale = relu(scale_) parameterization
        self.scale_ = nn.Parameter(torch.ones(nb_beta))

    @property
    def beta(self) -> torch.Tensor:
        """β = exp(γ)"""
        return torch.exp(self.gamma)

    @property
    def scale(self) -> torch.Tensor:
        """scale = relu(scale_)"""
        return F.relu(self.scale_)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Args:
            x: (B, 1, N) input signal
        Returns:
            (B, C_aug, N) where C_aug = 1 + nb_beta if include_original else nb_beta
        """
        B, C, N = x.shape
        beta = self.beta  # (nb_beta,)
        scale = self.scale  # (nb_beta,)

        # Compute GL weights
        weights = gl_weights(beta, self.K)  # (nb_beta, K)

        outputs = []
        if self.include_original:
            outputs.append(x)  # Original signal

        for i in range(self.nb_beta):
            # Backward derivative
            kernel_bwd = weights[i].flip(0).view(1, 1, -1)  # (1, 1, K)
            du_bwd = F.conv1d(x, kernel_bwd, padding=self.K - 1)[:, :, :N]

            # Forward derivative (flip signal, apply, flip back)
            x_flip = x.flip(-1)
            du_fwd = F.conv1d(x_flip, kernel_bwd, padding=self.K - 1)[:, :, :N].flip(-1)

            # Centered scheme: 0.5 * (backward + cos(πβ) * forward)
            cos_factor = torch.cos(np.pi * beta[i])
            deriv = 0.5 * (du_bwd + cos_factor * du_fwd)

            # Scale (stencil_only=True means no h^β normalization)
            deriv = scale[i] * deriv

            outputs.append(deriv)

        return torch.cat(outputs, dim=1)  # (B, C_aug, N)


class DELFNO1d(nn.Module):
    """
    DEL-FNO: FNO enhanced with learnable fractional derivatives.
    Architecture aligned with SPEC and neurops.py.

    Input augmentation: [u, D^β1 u, D^β2 u, x]
    """
    def __init__(self, space_dim: int = 1, fun_dim: int = 1, out_dim: int = 1,
                 n_hidden: int = 64, n_layers: int = 4, modes: int = 16,
                 nb_beta: int = 2, K: int = 16, init_betas: List[float] = [1.0, 2.0],
                 stencil_only: bool = True, include_original: bool = True):
        super().__init__()
        self.__name__ = 'DEL-FNO'
        self.space_dim = space_dim
        self.fun_dim = fun_dim
        self.out_dim = out_dim
        self.n_hidden = n_hidden
        self.n_layers = n_layers
        self.modes = modes
        self.nb_beta = nb_beta
        self.include_original = include_original

        # Fractional derivative bank
        self.frac_deriv = FracDerivBank(
            nb_beta=nb_beta, K=K, init_betas=init_betas,
            stencil_only=stencil_only, include_original=include_original
        )

        # Input dimension: (x, u, D^β1 u, D^β2 u, ...)
        # C_aug = 1 + nb_beta if include_original else nb_beta
        c_aug = (1 + nb_beta) if include_original else nb_beta
        in_dim = space_dim + c_aug  # x_coord + augmented channels

        # ═══ Preprocessing (neurops.py: MLP with 2× hidden expansion) ═══
        self.preprocess = MLP(in_dim, n_hidden * 2, n_hidden, n_layers=0, res=False, act='gelu')

        # ═══ FNO layers (fixed 4 blocks) ═══
        self.conv0 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv1 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv2 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.conv3 = SpectralConv1d(n_hidden, n_hidden, modes)
        self.w0 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w1 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w2 = nn.Conv1d(n_hidden, n_hidden, 1)
        self.w3 = nn.Conv1d(n_hidden, n_hidden, 1)

        # ═══ Output projection ═══
        self.fc1 = nn.Linear(n_hidden, n_hidden)
        self.fc2 = nn.Linear(n_hidden, out_dim)

    def get_beta_values(self) -> torch.Tensor:
        return self.frac_deriv.beta.detach().clone()

    def get_scale_values(self) -> torch.Tensor:
        return self.frac_deriv.scale.detach().clone()

    def forward(self, a: torch.Tensor) -> torch.Tensor:
        B, N = a.shape

        # Compute fractional derivatives: (B, 1, N) -> (B, C_aug, N)
        a_expanded = a.unsqueeze(1)
        derivs = self.frac_deriv(a_expanded)  # (B, C_aug, N) = (B, [u, D1, D2], N)

        # Grid coordinates
        x_grid = torch.linspace(0, 1, N, device=a.device).unsqueeze(0).expand(B, -1).unsqueeze(-1)

        # Concatenate: (x, u, D^β1 u, D^β2 u) -> (B, N, space_dim + C_aug)
        derivs = derivs.permute(0, 2, 1)  # (B, N, C_aug)
        x = torch.cat([x_grid, derivs], dim=-1)  # (B, N, 1 + C_aug) = (B, N, [x, u, D1, D2])

        # Preprocess
        fx = self.preprocess(x)

        # Reshape for conv
        x = fx.permute(0, 2, 1)  # (B, n_hidden, N)

        # FFT Padding
        padding = (16 - N % 16) % 16
        if padding > 0:
            x = F.pad(x, (0, padding))

        # 4 FNO blocks
        x = F.gelu(self.conv0(x) + self.w0(x))
        x = F.gelu(self.conv1(x) + self.w1(x))
        x = F.gelu(self.conv2(x) + self.w2(x))
        x = self.conv3(x) + self.w3(x)  # NO activation

        # Remove padding
        if padding > 0:
            x = x[..., :N]

        # Output projection
        x = x.permute(0, 2, 1)
        x = self.fc2(F.gelu(self.fc1(x)))

        return x.squeeze(-1)


def create_model(model_type: str, cfg: Config, modes: int = None) -> nn.Module:
    """Factory function to create models."""
    if modes is None:
        modes = cfg.modes

    if model_type == 'FNO':
        return FNO1d(
            space_dim=1, fun_dim=1, out_dim=1,
            n_hidden=cfg.n_hidden,
            n_layers=cfg.n_layers,
            modes=modes
        ).to(device)
    elif model_type == 'DEL-FNO':
        return DELFNO1d(
            space_dim=1, fun_dim=1, out_dim=1,
            n_hidden=cfg.n_hidden,
            n_layers=cfg.n_layers,
            modes=modes,
            nb_beta=cfg.nb_beta,
            K=cfg.K,
            init_betas=cfg.init_betas,
            stencil_only=cfg.stencil_only,
            include_original=cfg.include_original
        ).to(device)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

# %%
# @title Cell 7: Test Models
log.info("Testing models...")
test_input = torch.randn(4, cfg.resolution).to(device)

for name in cfg.models:
    model = create_model(name, cfg)
    out = model(test_input)
    n_params = sum(p.numel() for p in model.parameters())
    log.info(f"{name}: output={out.shape}, params={n_params:,}")

    if name == 'DEL-FNO':
        log.info(f"  Initial β: {model.get_beta_values().cpu().numpy()}")
        log.info(f"  Initial scale: {model.get_scale_values().cpu().numpy()}")

        # Test backward pass
        loss = out.sum()
        loss.backward()
        log.info(f"  γ gradient: {model.frac_deriv.gamma.grad}")
        log.info(f"  scale_ gradient: {model.frac_deriv.scale_.grad}")
        log.info("  Backward pass: OK")

log.info("Model tests passed!")
# Out:
# 17:01:55 | INFO | Testing models...
# INFO:DELFNO:Testing models...
# 17:01:55 | INFO | FNO: output=torch.Size([4, 1024]), params=291,649
# INFO:DELFNO:FNO: output=torch.Size([4, 1024]), params=291,649
# 17:01:55 | INFO | DEL-FNO: output=torch.Size([4, 1024]), params=291,909
# INFO:DELFNO:DEL-FNO: output=torch.Size([4, 1024]), params=291,909
# 17:01:55 | INFO |   Initial β: [1. 2.]
# INFO:DELFNO:  Initial β: [1. 2.]
# 17:01:55 | INFO |   Initial scale: [1. 1.]
# INFO:DELFNO:  Initial scale: [1. 1.]
# 17:01:55 | INFO |   γ gradient: tensor([ 0.1249, -0.8269], device='cuda:0')
# INFO:DELFNO:  γ gradient: tensor([ 0.1249, -0.8269], device='cuda:0')
# 17:01:55 | INFO |   scale_ gradient: tensor([ 0.1257, -1.2080], device='cuda:0')
# INFO:DELFNO:  scale_ gradient: tensor([ 0.1257, -1.2080], device='cuda:0')
# 17:01:55 | INFO |   Backward pass: OK
# INFO:DELFNO:  Backward pass: OK
# 17:01:55 | INFO | Model tests passed!
# INFO:DELFNO:Model tests passed!

# %%
# @title Cell 8: Training Infrastructure
# ═══════════════════════════════════════════════════════════════════
#                    TRAINING INFRASTRUCTURE
# ═══════════════════════════════════════════════════════════════════

def relative_l2_error(pred: torch.Tensor, target: torch.Tensor) -> torch.Tensor:
    """Compute relative L2 error: ||pred - target||_2 / ||target||_2"""
    diff_norm = torch.norm(pred - target, p=2, dim=-1)
    target_norm = torch.norm(target, p=2, dim=-1)
    return (diff_norm / target_norm.clamp(min=1e-8)).mean()


@dataclass
class TrainResult:
    """Container for training results."""
    test_error: float
    train_error: float
    beta_values: Optional[List[float]]
    scale_values: Optional[List[float]]
    train_time: float
    loss_history: List[float]
    beta_history: Optional[List[List[float]]]


def train_model(model: nn.Module, data: Dict[str, torch.Tensor],
                cfg: Config, epochs: int = None,
                run_logger: logging.Logger = None) -> TrainResult:
    """
    Train a model and return results.
    Uses OneCycleLR scheduler (from SPEC).
    """
    if epochs is None:
        epochs = cfg.epochs
    if run_logger is None:
        run_logger = log

    batch_size = cfg.batch_size
    n_train = data['a_train'].shape[0]

    # Adjust batch size if needed
    if batch_size > n_train:
        batch_size = n_train
        run_logger.warning(f"Reduced batch_size to {batch_size} (n_train={n_train})")

    # DataLoader
    train_dataset = TensorDataset(data['a_train'], data['u_train'])
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

    # Handle edge case where drop_last removes all batches
    steps_per_epoch = len(train_loader)
    if steps_per_epoch == 0:
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
        steps_per_epoch = len(train_loader)
        run_logger.warning(f"Using drop_last=False, steps_per_epoch={steps_per_epoch}")

    # Check if DEL-FNO
    is_del = hasattr(model, 'frac_deriv')

    # Optimizer with separate LR for β/scale (from SPEC)
    if is_del:
        del_params = list(model.frac_deriv.parameters())
        del_param_ids = {id(p) for p in del_params}
        other_params = [p for p in model.parameters() if id(p) not in del_param_ids]
        param_groups = [
            {'params': other_params, 'lr': cfg.lr, 'weight_decay': cfg.weight_decay},
            {'params': del_params, 'lr': cfg.lr_beta, 'weight_decay': cfg.wd_beta}  # No weight decay for β
        ]
    else:
        param_groups = [{'params': model.parameters(), 'lr': cfg.lr, 'weight_decay': cfg.weight_decay}]

    optimizer = torch.optim.AdamW(param_groups)

    # OneCycleLR scheduler (from SPEC)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=[cfg.lr, cfg.lr_beta] if is_del else [cfg.lr],
        epochs=epochs,
        steps_per_epoch=steps_per_epoch,
        pct_start=0.1,
        anneal_strategy='cos'
    )

    # Training loop
    loss_history = []
    beta_history = [] if is_del else None

    start_time = time.time()
    model.train()

    for epoch in range(epochs):
        epoch_loss = 0.0
        n_batches = 0

        for a_batch, u_batch in train_loader:
            optimizer.zero_grad()
            pred = model(a_batch)
            loss = relative_l2_error(pred, u_batch)
            loss.backward()

            if cfg.grad_clip > 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)

            optimizer.step()
            scheduler.step()

            epoch_loss += loss.item()
            n_batches += 1

        avg_loss = epoch_loss / max(n_batches, 1)
        loss_history.append(avg_loss)

        if is_del:
            beta_history.append(model.get_beta_values().cpu().tolist())

        # Logging
        if cfg.verbose and (epoch + 1) % cfg.log_interval == 0:
            msg = f"Epoch {epoch+1:4d}/{epochs}: loss={avg_loss:.6f}"
            if is_del:
                beta_str = ', '.join([f"{b:.4f}" for b in model.get_beta_values().cpu().numpy()])
                scale_str = ', '.join([f"{s:.4f}" for s in model.get_scale_values().cpu().numpy()])
                msg += f", β=[{beta_str}], scale=[{scale_str}]"
            run_logger.info(msg)

    train_time = time.time() - start_time

    # Evaluate
    model.eval()
    with torch.no_grad():
        train_pred = model(data['a_train'])
        train_error = relative_l2_error(train_pred, data['u_train']).item()

        test_pred = model(data['a_test'])
        test_error = relative_l2_error(test_pred, data['u_test']).item()

    return TrainResult(
        test_error=test_error,
        train_error=train_error,
        beta_values=model.get_beta_values().cpu().tolist() if is_del else None,
        scale_values=model.get_scale_values().cpu().tolist() if is_del else None,
        train_time=train_time,
        loss_history=loss_history,
        beta_history=beta_history,
    )

# %%
# @title Cell 9: Experiment Runner
# ═══════════════════════════════════════════════════════════════════
#                    EXPERIMENT RUNNER
# ═══════════════════════════════════════════════════════════════════

def run_single_experiment(model_type: str, cfg: Config, seed: int,
                          n_train: int = None, noise_level: float = 0.0,
                          modes: int = None, epochs: int = None,
                          raw_data: Dict = None,
                          run_logger: logging.Logger = None) -> Dict:
    """
    Run a single experiment with given parameters.
    """
    torch.manual_seed(seed)
    np.random.seed(seed)
    torch.cuda.manual_seed_all(seed)

    if modes is None:
        modes = cfg.modes
    if epochs is None:
        epochs = cfg.epochs
    if run_logger is None:
        run_logger = log

    # Load data if not provided
    if raw_data is None:
        raw_data = load_burgers_data(cfg)

    # Prepare splits
    data = prepare_data_splits(raw_data, cfg, n_train=n_train,
                               noise_level=noise_level, seed=seed)

    # Create and train model
    model = create_model(model_type, cfg, modes=modes)
    result = train_model(model, data, cfg, epochs=epochs, run_logger=run_logger)

    return {
        'model': model_type,
        'dataset': cfg.dataset,
        'seed': seed,
        'modes': modes,
        'n_train': data['n_train'],
        'noise_level': noise_level,
        'epochs': epochs,
        'test_error': result.test_error,
        'train_error': result.train_error,
        'beta_values': result.beta_values,
        'scale_values': result.scale_values,
        'train_time': result.train_time,
        'loss_history': result.loss_history,
        'beta_history': result.beta_history,
    }


def run_experiment_grid(experiment_name: str, variable_name: str,
                        variable_values: List, cfg: Config,
                        fixed_params: Dict = None) -> pd.DataFrame:
    """
    Run a grid of experiments varying one parameter.
    """
    if fixed_params is None:
        fixed_params = {}

    # Pre-load dataset
    log.info(f"Loading {cfg.dataset} data...")
    raw_data = load_burgers_data(cfg)

    total_runs = len(variable_values) * len(cfg.models) * len(cfg.seeds)
    log.info("="*60)
    log.info(f"Experiment: {experiment_name}")
    log.info(f"Dataset: {cfg.dataset}")
    log.info(f"Variable: {variable_name} = {variable_values}")
    log.info(f"Seeds: {cfg.seeds}")
    log.info(f"Total runs: {total_runs}")
    log.info("="*60)

    results = []
    pbar = tqdm(total=total_runs, desc=experiment_name)

    for value in variable_values:
        for model_type in cfg.models:
            for seed in cfg.seeds:
                # Build params
                params = {
                    'model_type': model_type,
                    'cfg': cfg,
                    'seed': seed,
                    'raw_data': raw_data,
                    **fixed_params,
                }
                params[variable_name] = value

                # Run
                log.info(f"Running: {model_type}, {variable_name}={value}, seed={seed}")
                result = run_single_experiment(**params)
                results.append(result)

                pbar.set_postfix({
                    variable_name: value,
                    'model': model_type[:3],
                    'err': f"{result['test_error']:.4f}"
                })
                pbar.update(1)

                # Log result
                log.info(f"  Result: test_err={result['test_error']:.6f}, "
                        f"train_err={result['train_error']:.6f}, "
                        f"time={result['train_time']:.1f}s")
                if result['beta_values']:
                    log.info(f"  Final β: {result['beta_values']}")

    pbar.close()

    df = pd.DataFrame(results)
    save_path = f"{cfg.results_dir}/{experiment_name}_{cfg.dataset}.csv"
    df.to_csv(save_path, index=False)
    log.info(f"Results saved to {save_path}")

    return df

# %%
# @title Cell 10: Load and Verify Data
log.info("Loading and verifying dataset...")

data_r10 = load_burgers_data(cfg)

# Visualize
fig, ax = plt.subplots(figsize=(10, 5))
x = np.linspace(0, 1, cfg.resolution)

for i in range(3):
    ax.plot(x, data_r10['a'][i].cpu(), '--', label=f'IC {i}', alpha=0.7)
    ax.plot(x, data_r10['u'][i].cpu(), '-', label=f'Sol {i}', linewidth=2)

ax.set_xlabel('x')
ax.set_ylabel('u')
ax.set_title(f'Burgers R={cfg.reynolds} (smooth solutions)')
ax.legend(loc='upper right', fontsize=8, ncol=2)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f"{cfg.results_dir}/data_verification_{cfg.dataset}.png", dpi=150, bbox_inches='tight')
plt.show()

log.info("Data verification complete.")
# Out:
# 17:01:55 | INFO | Loading and verifying dataset...
# INFO:DELFNO:Loading and verifying dataset...
# 17:01:55 | INFO | Loading: ./data/burgers_r10.mat (644.4MB)
# INFO:DELFNO:Loading: ./data/burgers_r10.mat (644.4MB)
# 17:01:59 | INFO |   scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# INFO:DELFNO:  scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# 17:01:59 | INFO |   Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# INFO:DELFNO:  Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# 17:01:59 | INFO |   Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# INFO:DELFNO:  Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# 17:01:59 | INFO | Data verification complete.
# INFO:DELFNO:Data verification complete.

# %%
# @title Cell 11: Experiment 1 - Noise Robustness
log.info("="*60)
log.info("EXPERIMENT 1: NOISE ROBUSTNESS")
log.info("="*60)

df_noise = run_experiment_grid(
    experiment_name='exp1_noise_robustness',
    variable_name='noise_level',
    variable_values=cfg.noise_levels,
    cfg=cfg,
    fixed_params={'n_train': cfg.n_train, 'modes': cfg.modes}
)

log.info(f"Experiment 1 complete! Shape: {df_noise.shape}")
# Out:
# 17:01:59 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 17:01:59 | INFO | EXPERIMENT 1: NOISE ROBUSTNESS
# INFO:DELFNO:EXPERIMENT 1: NOISE ROBUSTNESS
# 17:01:59 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 17:01:59 | INFO | Loading r10 data...
# INFO:DELFNO:Loading r10 data...
# 17:01:59 | INFO | Loading: ./data/burgers_r10.mat (644.4MB)
# INFO:DELFNO:Loading: ./data/burgers_r10.mat (644.4MB)
# 17:02:04 | INFO |   scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# INFO:DELFNO:  scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# 17:02:04 | INFO |   Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# INFO:DELFNO:  Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# 17:02:04 | INFO |   Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# INFO:DELFNO:  Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# 17:02:04 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 17:02:04 | INFO | Experiment: exp1_noise_robustness
# INFO:DELFNO:Experiment: exp1_noise_robustness
# 17:02:04 | INFO | Dataset: r10
# INFO:DELFNO:Dataset: r10
# 17:02:04 | INFO | Variable: noise_level = [0.0, 0.01, 0.02, 0.05, 0.1]
# INFO:DELFNO:Variable: noise_level = [0.0, 0.01, 0.02, 0.05, 0.1]
# 17:02:04 | INFO | Seeds: [42, 108, 888]
# INFO:DELFNO:Seeds: [42, 108, 888]
# 17:02:04 | INFO | Total runs: 30
# INFO:DELFNO:Total runs: 30
# 17:02:04 | INFO | ============================================================
# INFO:DELFNO:============================================================
# exp1_noise_robustness:   0%|          | 0/30 [00:00<?, ?it/s]
# 17:02:04 | INFO | Running: FNO, noise_level=0.0, seed=42
# INFO:DELFNO:Running: FNO, noise_level=0.0, seed=42
# 17:03:44 | INFO | Epoch  100/500: loss=0.020332
# INFO:DELFNO:Epoch  100/500: loss=0.020332
# 17:05:23 | INFO | Epoch  200/500: loss=0.013341
# INFO:DELFNO:Epoch  200/500: loss=0.013341
# 17:07:02 | INFO | Epoch  300/500: loss=0.005252
# INFO:DELFNO:Epoch  300/500: loss=0.005252
# 17:08:41 | INFO | Epoch  400/500: loss=0.001376
# INFO:DELFNO:Epoch  400/500: loss=0.001376
# 17:10:20 | INFO | Epoch  500/500: loss=0.000333
# INFO:DELFNO:Epoch  500/500: loss=0.000333
# 17:10:20 | INFO |   Result: test_err=0.000852, train_err=0.000565, time=496.4s
# INFO:DELFNO:  Result: test_err=0.000852, train_err=0.000565, time=496.4s
# 17:10:20 | INFO | Running: FNO, noise_level=0.0, seed=108
# INFO:DELFNO:Running: FNO, noise_level=0.0, seed=108
# 17:12:00 | INFO | Epoch  100/500: loss=0.020790
# INFO:DELFNO:Epoch  100/500: loss=0.020790
# 17:13:41 | INFO | Epoch  200/500: loss=0.010817
# INFO:DELFNO:Epoch  200/500: loss=0.010817
# 17:15:21 | INFO | Epoch  300/500: loss=0.005295
# INFO:DELFNO:Epoch  300/500: loss=0.005295
# 17:17:05 | INFO | Epoch  400/500: loss=0.001502
# INFO:DELFNO:Epoch  400/500: loss=0.001502
# 17:18:46 | INFO | Epoch  500/500: loss=0.000325
# INFO:DELFNO:Epoch  500/500: loss=0.000325
# 17:18:46 | INFO |   Result: test_err=0.000759, train_err=0.000515, time=505.4s
# INFO:DELFNO:  Result: test_err=0.000759, train_err=0.000515, time=505.4s
# 17:18:46 | INFO | Running: FNO, noise_level=0.0, seed=888
# INFO:DELFNO:Running: FNO, noise_level=0.0, seed=888
# 17:20:26 | INFO | Epoch  100/500: loss=0.025433
# INFO:DELFNO:Epoch  100/500: loss=0.025433
# 17:22:07 | INFO | Epoch  200/500: loss=0.010580
# INFO:DELFNO:Epoch  200/500: loss=0.010580
# 17:23:47 | INFO | Epoch  300/500: loss=0.004750
# INFO:DELFNO:Epoch  300/500: loss=0.004750
# 17:25:28 | INFO | Epoch  400/500: loss=0.001337
# INFO:DELFNO:Epoch  400/500: loss=0.001337
# 17:27:07 | INFO | Epoch  500/500: loss=0.000304
# INFO:DELFNO:Epoch  500/500: loss=0.000304
# 17:27:07 | INFO |   Result: test_err=0.000744, train_err=0.000447, time=501.6s
# INFO:DELFNO:  Result: test_err=0.000744, train_err=0.000447, time=501.6s
# 17:27:07 | INFO | Running: DEL-FNO, noise_level=0.0, seed=42
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.0, seed=42
# 17:29:44 | INFO | Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# 17:32:30 | INFO | Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 17:35:16 | INFO | Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 17:38:02 | INFO | Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 17:40:49 | INFO | Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 17:40:49 | INFO |   Result: test_err=0.000676, train_err=0.000436, time=821.5s
# INFO:DELFNO:  Result: test_err=0.000676, train_err=0.000436, time=821.5s
# 17:40:49 | INFO |   Final β: [1.288582444190979, 2.3165488243103027]
# INFO:DELFNO:  Final β: [1.288582444190979, 2.3165488243103027]
# 17:40:49 | INFO | Running: DEL-FNO, noise_level=0.0, seed=108
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.0, seed=108
# 17:43:36 | INFO | Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# INFO:DELFNO:Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# 17:46:20 | INFO | Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 17:49:06 | INFO | Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 17:51:53 | INFO | Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 17:54:39 | INFO | Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 17:54:39 | INFO |   Result: test_err=0.000741, train_err=0.000509, time=830.3s
# INFO:DELFNO:  Result: test_err=0.000741, train_err=0.000509, time=830.3s
# 17:54:39 | INFO |   Final β: [1.9527373313903809, 1.9374629259109497]
# INFO:DELFNO:  Final β: [1.9527373313903809, 1.9374629259109497]
# 17:54:39 | INFO | Running: DEL-FNO, noise_level=0.0, seed=888
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.0, seed=888
# 17:57:26 | INFO | Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# INFO:DELFNO:Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# 18:00:12 | INFO | Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 18:02:52 | INFO | Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 18:05:36 | INFO | Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 18:08:22 | INFO | Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 18:08:22 | INFO |   Result: test_err=0.000629, train_err=0.000409, time=822.7s
# INFO:DELFNO:  Result: test_err=0.000629, train_err=0.000409, time=822.7s
# 18:08:22 | INFO |   Final β: [1.3419767618179321, 2.044556140899658]
# INFO:DELFNO:  Final β: [1.3419767618179321, 2.044556140899658]
# 18:08:22 | INFO | Running: FNO, noise_level=0.01, seed=42
# INFO:DELFNO:Running: FNO, noise_level=0.01, seed=42
# 18:10:08 | INFO | Epoch  100/500: loss=0.025675
# INFO:DELFNO:Epoch  100/500: loss=0.025675
# 18:11:53 | INFO | Epoch  200/500: loss=0.010552
# INFO:DELFNO:Epoch  200/500: loss=0.010552
# 18:13:39 | INFO | Epoch  300/500: loss=0.004788
# INFO:DELFNO:Epoch  300/500: loss=0.004788
# 18:15:24 | INFO | Epoch  400/500: loss=0.001859
# INFO:DELFNO:Epoch  400/500: loss=0.001859
# 18:17:09 | INFO | Epoch  500/500: loss=0.000877
# INFO:DELFNO:Epoch  500/500: loss=0.000877
# 18:17:09 | INFO |   Result: test_err=0.000853, train_err=0.000940, time=526.9s
# INFO:DELFNO:  Result: test_err=0.000853, train_err=0.000940, time=526.9s
# 18:17:09 | INFO | Running: FNO, noise_level=0.01, seed=108
# INFO:DELFNO:Running: FNO, noise_level=0.01, seed=108
# 18:18:54 | INFO | Epoch  100/500: loss=0.020338
# INFO:DELFNO:Epoch  100/500: loss=0.020338
# 18:20:36 | INFO | Epoch  200/500: loss=0.011665
# INFO:DELFNO:Epoch  200/500: loss=0.011665
# 18:22:21 | INFO | Epoch  300/500: loss=0.005034
# INFO:DELFNO:Epoch  300/500: loss=0.005034
# 18:24:06 | INFO | Epoch  400/500: loss=0.001508
# INFO:DELFNO:Epoch  400/500: loss=0.001508
# 18:25:52 | INFO | Epoch  500/500: loss=0.000855
# INFO:DELFNO:Epoch  500/500: loss=0.000855
# 18:25:52 | INFO |   Result: test_err=0.000963, train_err=0.000922, time=522.5s
# INFO:DELFNO:  Result: test_err=0.000963, train_err=0.000922, time=522.5s
# 18:25:52 | INFO | Running: FNO, noise_level=0.01, seed=888
# INFO:DELFNO:Running: FNO, noise_level=0.01, seed=888
# 18:27:37 | INFO | Epoch  100/500: loss=0.022230
# INFO:DELFNO:Epoch  100/500: loss=0.022230
# 18:29:22 | INFO | Epoch  200/500: loss=0.010478
# INFO:DELFNO:Epoch  200/500: loss=0.010478
# 18:31:07 | INFO | Epoch  300/500: loss=0.006048
# INFO:DELFNO:Epoch  300/500: loss=0.006048
# 18:32:53 | INFO | Epoch  400/500: loss=0.001667
# INFO:DELFNO:Epoch  400/500: loss=0.001667
# 18:34:38 | INFO | Epoch  500/500: loss=0.000860
# INFO:DELFNO:Epoch  500/500: loss=0.000860
# 18:34:38 | INFO |   Result: test_err=0.000961, train_err=0.000936, time=526.1s
# INFO:DELFNO:  Result: test_err=0.000961, train_err=0.000936, time=526.1s
# 18:34:38 | INFO | Running: DEL-FNO, noise_level=0.01, seed=42
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.01, seed=42
# 18:37:23 | INFO | Epoch  100/500: loss=0.020508, β=[0.8246, 3.7524], scale=[0.5410, 0.2824]
# INFO:DELFNO:Epoch  100/500: loss=0.020508, β=[0.8246, 3.7524], scale=[0.5410, 0.2824]
# 18:40:09 | INFO | Epoch  200/500: loss=0.014392, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.014392, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# 18:42:56 | INFO | Epoch  300/500: loss=0.004541, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004541, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# 18:45:42 | INFO | Epoch  400/500: loss=0.001706, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001706, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# 18:48:28 | INFO | Epoch  500/500: loss=0.000898, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000898, β=[1.3397, 4.2783], scale=[0.0000, 0.0000]
# 18:48:28 | INFO |   Result: test_err=0.000764, train_err=0.000933, time=830.2s
# INFO:DELFNO:  Result: test_err=0.000764, train_err=0.000933, time=830.2s
# 18:48:28 | INFO |   Final β: [1.339747667312622, 4.2783203125]
# INFO:DELFNO:  Final β: [1.339747667312622, 4.2783203125]
# 18:48:28 | INFO | Running: DEL-FNO, noise_level=0.01, seed=108
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.01, seed=108
# 18:51:14 | INFO | Epoch  100/500: loss=0.022548, β=[0.7423, 1.6254], scale=[0.1040, 1.2443]
# INFO:DELFNO:Epoch  100/500: loss=0.022548, β=[0.7423, 1.6254], scale=[0.1040, 1.2443]
# 18:53:50 | INFO | Epoch  200/500: loss=0.012071, β=[0.7557, 1.6975], scale=[0.0000, 0.7109]
# INFO:DELFNO:Epoch  200/500: loss=0.012071, β=[0.7557, 1.6975], scale=[0.0000, 0.7109]
# 18:56:25 | INFO | Epoch  300/500: loss=0.006783, β=[0.7557, 1.8561], scale=[0.0000, 0.5825]
# INFO:DELFNO:Epoch  300/500: loss=0.006783, β=[0.7557, 1.8561], scale=[0.0000, 0.5825]
# 18:59:00 | INFO | Epoch  400/500: loss=0.001753, β=[0.7557, 1.8850], scale=[0.0000, 0.6774]
# INFO:DELFNO:Epoch  400/500: loss=0.001753, β=[0.7557, 1.8850], scale=[0.0000, 0.6774]
# 19:01:36 | INFO | Epoch  500/500: loss=0.000888, β=[0.7557, 1.9084], scale=[0.0000, 0.7736]
# INFO:DELFNO:Epoch  500/500: loss=0.000888, β=[0.7557, 1.9084], scale=[0.0000, 0.7736]
# 19:01:36 | INFO |   Result: test_err=0.000822, train_err=0.000944, time=787.2s
# INFO:DELFNO:  Result: test_err=0.000822, train_err=0.000944, time=787.2s
# 19:01:36 | INFO |   Final β: [0.7557144165039062, 1.9084159135818481]
# INFO:DELFNO:  Final β: [0.7557144165039062, 1.9084159135818481]
# 19:01:36 | INFO | Running: DEL-FNO, noise_level=0.01, seed=888
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.01, seed=888
# 19:04:11 | INFO | Epoch  100/500: loss=0.020542, β=[1.4166, 1.6537], scale=[1.0623, 1.8029]
# INFO:DELFNO:Epoch  100/500: loss=0.020542, β=[1.4166, 1.6537], scale=[1.0623, 1.8029]
# 19:06:46 | INFO | Epoch  200/500: loss=0.011052, β=[1.4389, 1.7746], scale=[0.1888, 0.9203]
# INFO:DELFNO:Epoch  200/500: loss=0.011052, β=[1.4389, 1.7746], scale=[0.1888, 0.9203]
# 19:09:22 | INFO | Epoch  300/500: loss=0.004750, β=[1.3857, 2.0991], scale=[0.0000, 0.5814]
# INFO:DELFNO:Epoch  300/500: loss=0.004750, β=[1.3857, 2.0991], scale=[0.0000, 0.5814]
# 19:11:57 | INFO | Epoch  400/500: loss=0.001808, β=[1.3857, 1.9860], scale=[0.0000, 0.7198]
# INFO:DELFNO:Epoch  400/500: loss=0.001808, β=[1.3857, 1.9860], scale=[0.0000, 0.7198]
# 19:14:32 | INFO | Epoch  500/500: loss=0.000906, β=[1.3857, 1.9849], scale=[0.0000, 0.8327]
# INFO:DELFNO:Epoch  500/500: loss=0.000906, β=[1.3857, 1.9849], scale=[0.0000, 0.8327]
# 19:14:32 | INFO |   Result: test_err=0.000833, train_err=0.000954, time=776.1s
# INFO:DELFNO:  Result: test_err=0.000833, train_err=0.000954, time=776.1s
# 19:14:32 | INFO |   Final β: [1.385665774345398, 1.98491632938385]
# INFO:DELFNO:  Final β: [1.385665774345398, 1.98491632938385]
# 19:14:32 | INFO | Running: FNO, noise_level=0.02, seed=42
# INFO:DELFNO:Running: FNO, noise_level=0.02, seed=42
# 19:16:12 | INFO | Epoch  100/500: loss=0.023449
# INFO:DELFNO:Epoch  100/500: loss=0.023449
# 19:17:51 | INFO | Epoch  200/500: loss=0.009755
# INFO:DELFNO:Epoch  200/500: loss=0.009755
# 19:19:32 | INFO | Epoch  300/500: loss=0.006617
# INFO:DELFNO:Epoch  300/500: loss=0.006617
# 19:21:12 | INFO | Epoch  400/500: loss=0.002450
# INFO:DELFNO:Epoch  400/500: loss=0.002450
# 19:22:52 | INFO | Epoch  500/500: loss=0.001544
# INFO:DELFNO:Epoch  500/500: loss=0.001544
# 19:22:52 | INFO |   Result: test_err=0.001217, train_err=0.001575, time=499.7s
# INFO:DELFNO:  Result: test_err=0.001217, train_err=0.001575, time=499.7s
# 19:22:52 | INFO | Running: FNO, noise_level=0.02, seed=108
# INFO:DELFNO:Running: FNO, noise_level=0.02, seed=108
# 19:24:31 | INFO | Epoch  100/500: loss=0.022063
# INFO:DELFNO:Epoch  100/500: loss=0.022063
# 19:26:11 | INFO | Epoch  200/500: loss=0.012873
# INFO:DELFNO:Epoch  200/500: loss=0.012873
# 19:27:51 | INFO | Epoch  300/500: loss=0.006119
# INFO:DELFNO:Epoch  300/500: loss=0.006119
# 19:29:31 | INFO | Epoch  400/500: loss=0.002409
# INFO:DELFNO:Epoch  400/500: loss=0.002409
# 19:31:11 | INFO | Epoch  500/500: loss=0.001505
# INFO:DELFNO:Epoch  500/500: loss=0.001505
# 19:31:11 | INFO |   Result: test_err=0.001359, train_err=0.001539, time=499.7s
# INFO:DELFNO:  Result: test_err=0.001359, train_err=0.001539, time=499.7s
# 19:31:11 | INFO | Running: FNO, noise_level=0.02, seed=888
# INFO:DELFNO:Running: FNO, noise_level=0.02, seed=888
# 19:32:51 | INFO | Epoch  100/500: loss=0.019947
# INFO:DELFNO:Epoch  100/500: loss=0.019947
# 19:34:31 | INFO | Epoch  200/500: loss=0.010824
# INFO:DELFNO:Epoch  200/500: loss=0.010824
# 19:36:10 | INFO | Epoch  300/500: loss=0.006549
# INFO:DELFNO:Epoch  300/500: loss=0.006549
# 19:37:50 | INFO | Epoch  400/500: loss=0.002269
# INFO:DELFNO:Epoch  400/500: loss=0.002269
# 19:39:29 | INFO | Epoch  500/500: loss=0.001535
# INFO:DELFNO:Epoch  500/500: loss=0.001535
# 19:39:29 | INFO |   Result: test_err=0.001364, train_err=0.001567, time=497.8s
# INFO:DELFNO:  Result: test_err=0.001364, train_err=0.001567, time=497.8s
# 19:39:29 | INFO | Running: DEL-FNO, noise_level=0.02, seed=42
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.02, seed=42
# 19:42:05 | INFO | Epoch  100/500: loss=0.027574, β=[0.6547, 1.7248], scale=[1.0685, 0.9651]
# INFO:DELFNO:Epoch  100/500: loss=0.027574, β=[0.6547, 1.7248], scale=[1.0685, 0.9651]
# 19:44:40 | INFO | Epoch  200/500: loss=0.011559, β=[0.7924, 2.2272], scale=[0.1180, 0.9607]
# INFO:DELFNO:Epoch  200/500: loss=0.011559, β=[0.7924, 2.2272], scale=[0.1180, 0.9607]
# 19:47:15 | INFO | Epoch  300/500: loss=0.005367, β=[0.8175, 2.2002], scale=[0.0000, 0.6094]
# INFO:DELFNO:Epoch  300/500: loss=0.005367, β=[0.8175, 2.2002], scale=[0.0000, 0.6094]
# 19:49:50 | INFO | Epoch  400/500: loss=0.002387, β=[0.8175, 2.1218], scale=[0.0000, 0.7469]
# INFO:DELFNO:Epoch  400/500: loss=0.002387, β=[0.8175, 2.1218], scale=[0.0000, 0.7469]
# 19:52:25 | INFO | Epoch  500/500: loss=0.001580, β=[0.8175, 2.0914], scale=[0.0000, 0.8193]
# INFO:DELFNO:Epoch  500/500: loss=0.001580, β=[0.8175, 2.0914], scale=[0.0000, 0.8193]
# 19:52:25 | INFO |   Result: test_err=0.001134, train_err=0.001598, time=775.6s
# INFO:DELFNO:  Result: test_err=0.001134, train_err=0.001598, time=775.6s
# 19:52:25 | INFO |   Final β: [0.8175373077392578, 2.0914361476898193]
# INFO:DELFNO:  Final β: [0.8175373077392578, 2.0914361476898193]
# 19:52:25 | INFO | Running: DEL-FNO, noise_level=0.02, seed=108
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.02, seed=108
# 19:55:00 | INFO | Epoch  100/500: loss=0.019218, β=[0.6731, 1.6202], scale=[0.3426, 1.4254]
# INFO:DELFNO:Epoch  100/500: loss=0.019218, β=[0.6731, 1.6202], scale=[0.3426, 1.4254]
# 19:57:35 | INFO | Epoch  200/500: loss=0.014723, β=[0.7260, 1.6922], scale=[0.0000, 1.0450]
# INFO:DELFNO:Epoch  200/500: loss=0.014723, β=[0.7260, 1.6922], scale=[0.0000, 1.0450]
# 20:00:10 | INFO | Epoch  300/500: loss=0.006169, β=[0.7260, 1.7077], scale=[0.0000, 0.9916]
# INFO:DELFNO:Epoch  300/500: loss=0.006169, β=[0.7260, 1.7077], scale=[0.0000, 0.9916]
# 20:02:45 | INFO | Epoch  400/500: loss=0.002259, β=[0.7260, 1.7514], scale=[0.0000, 1.0820]
# INFO:DELFNO:Epoch  400/500: loss=0.002259, β=[0.7260, 1.7514], scale=[0.0000, 1.0820]
# 20:05:21 | INFO | Epoch  500/500: loss=0.001557, β=[0.7260, 1.8209], scale=[0.0000, 1.2324]
# INFO:DELFNO:Epoch  500/500: loss=0.001557, β=[0.7260, 1.8209], scale=[0.0000, 1.2324]
# 20:05:21 | INFO |   Result: test_err=0.001178, train_err=0.001590, time=775.4s
# INFO:DELFNO:  Result: test_err=0.001178, train_err=0.001590, time=775.4s
# 20:05:21 | INFO |   Final β: [0.7259649634361267, 1.8209245204925537]
# INFO:DELFNO:  Final β: [0.7259649634361267, 1.8209245204925537]
# 20:05:21 | INFO | Running: DEL-FNO, noise_level=0.02, seed=888
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.02, seed=888
# 20:07:55 | INFO | Epoch  100/500: loss=0.022684, β=[1.2267, 1.5877], scale=[1.0975, 1.8640]
# INFO:DELFNO:Epoch  100/500: loss=0.022684, β=[1.2267, 1.5877], scale=[1.0975, 1.8640]
# 20:10:30 | INFO | Epoch  200/500: loss=0.010539, β=[1.4597, 1.7504], scale=[0.2819, 1.2827]
# INFO:DELFNO:Epoch  200/500: loss=0.010539, β=[1.4597, 1.7504], scale=[0.2819, 1.2827]
# 20:13:05 | INFO | Epoch  300/500: loss=0.005098, β=[1.3986, 1.7920], scale=[0.0322, 1.1452]
# INFO:DELFNO:Epoch  300/500: loss=0.005098, β=[1.3986, 1.7920], scale=[0.0322, 1.1452]
# 20:15:40 | INFO | Epoch  400/500: loss=0.002574, β=[1.3623, 1.9579], scale=[0.0000, 1.3900]
# INFO:DELFNO:Epoch  400/500: loss=0.002574, β=[1.3623, 1.9579], scale=[0.0000, 1.3900]
# 20:18:16 | INFO | Epoch  500/500: loss=0.001585, β=[1.3623, 2.0854], scale=[0.0000, 1.6250]
# INFO:DELFNO:Epoch  500/500: loss=0.001585, β=[1.3623, 2.0854], scale=[0.0000, 1.6250]
# 20:18:16 | INFO |   Result: test_err=0.001241, train_err=0.001613, time=775.0s
# INFO:DELFNO:  Result: test_err=0.001241, train_err=0.001613, time=775.0s
# 20:18:16 | INFO |   Final β: [1.3623133897781372, 2.08536434173584]
# INFO:DELFNO:  Final β: [1.3623133897781372, 2.08536434173584]
# 20:18:16 | INFO | Running: FNO, noise_level=0.05, seed=42
# INFO:DELFNO:Running: FNO, noise_level=0.05, seed=42
# 20:19:55 | INFO | Epoch  100/500: loss=0.022095
# INFO:DELFNO:Epoch  100/500: loss=0.022095
# 20:21:35 | INFO | Epoch  200/500: loss=0.011737
# INFO:DELFNO:Epoch  200/500: loss=0.011737
# 20:23:15 | INFO | Epoch  300/500: loss=0.006203
# INFO:DELFNO:Epoch  300/500: loss=0.006203
# 20:24:55 | INFO | Epoch  400/500: loss=0.003817
# INFO:DELFNO:Epoch  400/500: loss=0.003817
# 20:26:34 | INFO | Epoch  500/500: loss=0.002679
# INFO:DELFNO:Epoch  500/500: loss=0.002679
# 20:26:34 | INFO |   Result: test_err=0.003523, train_err=0.002698, time=498.5s
# INFO:DELFNO:  Result: test_err=0.003523, train_err=0.002698, time=498.5s
# 20:26:34 | INFO | Running: FNO, noise_level=0.05, seed=108
# INFO:DELFNO:Running: FNO, noise_level=0.05, seed=108
# 20:28:14 | INFO | Epoch  100/500: loss=0.020401
# INFO:DELFNO:Epoch  100/500: loss=0.020401
# 20:29:54 | INFO | Epoch  200/500: loss=0.012979
# INFO:DELFNO:Epoch  200/500: loss=0.012979
# 20:31:34 | INFO | Epoch  300/500: loss=0.006485
# INFO:DELFNO:Epoch  300/500: loss=0.006485
# 20:33:13 | INFO | Epoch  400/500: loss=0.003702
# INFO:DELFNO:Epoch  400/500: loss=0.003702
# 20:34:53 | INFO | Epoch  500/500: loss=0.002474
# INFO:DELFNO:Epoch  500/500: loss=0.002474
# 20:34:53 | INFO |   Result: test_err=0.003763, train_err=0.002491, time=498.7s
# INFO:DELFNO:  Result: test_err=0.003763, train_err=0.002491, time=498.7s
# 20:34:53 | INFO | Running: FNO, noise_level=0.05, seed=888
# INFO:DELFNO:Running: FNO, noise_level=0.05, seed=888
# 20:36:33 | INFO | Epoch  100/500: loss=0.020746
# INFO:DELFNO:Epoch  100/500: loss=0.020746
# 20:38:12 | INFO | Epoch  200/500: loss=0.011905
# INFO:DELFNO:Epoch  200/500: loss=0.011905
# 20:39:52 | INFO | Epoch  300/500: loss=0.006457
# INFO:DELFNO:Epoch  300/500: loss=0.006457
# 20:41:32 | INFO | Epoch  400/500: loss=0.003641
# INFO:DELFNO:Epoch  400/500: loss=0.003641
# 20:43:11 | INFO | Epoch  500/500: loss=0.002446
# INFO:DELFNO:Epoch  500/500: loss=0.002446
# 20:43:11 | INFO |   Result: test_err=0.004007, train_err=0.002466, time=498.0s
# INFO:DELFNO:  Result: test_err=0.004007, train_err=0.002466, time=498.0s
# 20:43:11 | INFO | Running: DEL-FNO, noise_level=0.05, seed=42
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.05, seed=42
# 20:45:47 | INFO | Epoch  100/500: loss=0.027711, β=[0.5604, 3.1535], scale=[1.4598, 0.6446]
# INFO:DELFNO:Epoch  100/500: loss=0.027711, β=[0.5604, 3.1535], scale=[1.4598, 0.6446]
# 20:48:22 | INFO | Epoch  200/500: loss=0.011979, β=[0.5850, 4.1383], scale=[0.9934, 0.2616]
# INFO:DELFNO:Epoch  200/500: loss=0.011979, β=[0.5850, 4.1383], scale=[0.9934, 0.2616]
# 20:50:57 | INFO | Epoch  300/500: loss=0.007488, β=[0.6384, 4.0849], scale=[0.4616, 0.6666]
# INFO:DELFNO:Epoch  300/500: loss=0.007488, β=[0.6384, 4.0849], scale=[0.4616, 0.6666]
# 20:53:33 | INFO | Epoch  400/500: loss=0.003974, β=[0.6487, 4.0821], scale=[0.4051, 1.4153]
# INFO:DELFNO:Epoch  400/500: loss=0.003974, β=[0.6487, 4.0821], scale=[0.4051, 1.4153]
# 20:56:10 | INFO | Epoch  500/500: loss=0.002770, β=[0.6485, 4.1236], scale=[0.4186, 1.5930]
# INFO:DELFNO:Epoch  500/500: loss=0.002770, β=[0.6485, 4.1236], scale=[0.4186, 1.5930]
# 20:56:10 | INFO |   Result: test_err=0.003289, train_err=0.002782, time=778.6s
# INFO:DELFNO:  Result: test_err=0.003289, train_err=0.002782, time=778.6s
# 20:56:10 | INFO |   Final β: [0.6484732031822205, 4.123621940612793]
# INFO:DELFNO:  Final β: [0.6484732031822205, 4.123621940612793]
# 20:56:10 | INFO | Running: DEL-FNO, noise_level=0.05, seed=108
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.05, seed=108
# 20:58:48 | INFO | Epoch  100/500: loss=0.021584, β=[0.5233, 1.6748], scale=[1.3907, 1.1667]
# INFO:DELFNO:Epoch  100/500: loss=0.021584, β=[0.5233, 1.6748], scale=[1.3907, 1.1667]
# 21:01:25 | INFO | Epoch  200/500: loss=0.011064, β=[0.5227, 1.7617], scale=[0.3960, 1.1731]
# INFO:DELFNO:Epoch  200/500: loss=0.011064, β=[0.5227, 1.7617], scale=[0.3960, 1.1731]
# 21:04:02 | INFO | Epoch  300/500: loss=0.008138, β=[0.7205, 2.1561], scale=[0.0341, 2.0905]
# INFO:DELFNO:Epoch  300/500: loss=0.008138, β=[0.7205, 2.1561], scale=[0.0341, 2.0905]
# 21:06:39 | INFO | Epoch  400/500: loss=0.003516, β=[0.7695, 2.1248], scale=[0.0000, 2.9840]
# INFO:DELFNO:Epoch  400/500: loss=0.003516, β=[0.7695, 2.1248], scale=[0.0000, 2.9840]
# 21:09:14 | INFO | Epoch  500/500: loss=0.002419, β=[0.7695, 2.1341], scale=[0.0000, 3.1084]
# INFO:DELFNO:Epoch  500/500: loss=0.002419, β=[0.7695, 2.1341], scale=[0.0000, 3.1084]
# 21:09:14 | INFO |   Result: test_err=0.003309, train_err=0.002442, time=783.8s
# INFO:DELFNO:  Result: test_err=0.003309, train_err=0.002442, time=783.8s
# 21:09:14 | INFO |   Final β: [0.7695000171661377, 2.134066581726074]
# INFO:DELFNO:  Final β: [0.7695000171661377, 2.134066581726074]
# 21:09:14 | INFO | Running: DEL-FNO, noise_level=0.05, seed=888
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.05, seed=888
# 21:11:50 | INFO | Epoch  100/500: loss=0.025560, β=[1.2094, 1.6105], scale=[1.2762, 1.7288]
# INFO:DELFNO:Epoch  100/500: loss=0.025560, β=[1.2094, 1.6105], scale=[1.2762, 1.7288]
# 21:14:26 | INFO | Epoch  200/500: loss=0.011531, β=[1.5326, 1.7928], scale=[0.3047, 1.4013]
# INFO:DELFNO:Epoch  200/500: loss=0.011531, β=[1.5326, 1.7928], scale=[0.3047, 1.4013]
# 21:17:02 | INFO | Epoch  300/500: loss=0.008294, β=[1.8110, 2.1579], scale=[0.4795, 2.3961]
# INFO:DELFNO:Epoch  300/500: loss=0.008294, β=[1.8110, 2.1579], scale=[0.4795, 2.3961]
# 21:19:37 | INFO | Epoch  400/500: loss=0.003696, β=[2.0905, 2.1477], scale=[1.2339, 3.0627]
# INFO:DELFNO:Epoch  400/500: loss=0.003696, β=[2.0905, 2.1477], scale=[1.2339, 3.0627]
# 21:22:12 | INFO | Epoch  500/500: loss=0.002457, β=[2.1032, 2.1522], scale=[1.3860, 3.2162]
# INFO:DELFNO:Epoch  500/500: loss=0.002457, β=[2.1032, 2.1522], scale=[1.3860, 3.2162]
# 21:22:12 | INFO |   Result: test_err=0.003556, train_err=0.002479, time=777.8s
# INFO:DELFNO:  Result: test_err=0.003556, train_err=0.002479, time=777.8s
# 21:22:12 | INFO |   Final β: [2.1032097339630127, 2.1521706581115723]
# INFO:DELFNO:  Final β: [2.1032097339630127, 2.1521706581115723]
# 21:22:12 | INFO | Running: FNO, noise_level=0.1, seed=42
# INFO:DELFNO:Running: FNO, noise_level=0.1, seed=42
# 21:23:52 | INFO | Epoch  100/500: loss=0.025594
# INFO:DELFNO:Epoch  100/500: loss=0.025594
# 21:25:33 | INFO | Epoch  200/500: loss=0.015135
# INFO:DELFNO:Epoch  200/500: loss=0.015135
# 21:27:12 | INFO | Epoch  300/500: loss=0.007504
# INFO:DELFNO:Epoch  300/500: loss=0.007504
# 21:28:51 | INFO | Epoch  400/500: loss=0.003715
# INFO:DELFNO:Epoch  400/500: loss=0.003715
# 21:30:32 | INFO | Epoch  500/500: loss=0.002339
# INFO:DELFNO:Epoch  500/500: loss=0.002339
# 21:30:32 | INFO |   Result: test_err=0.008414, train_err=0.002376, time=499.7s
# INFO:DELFNO:  Result: test_err=0.008414, train_err=0.002376, time=499.7s
# 21:30:32 | INFO | Running: FNO, noise_level=0.1, seed=108
# INFO:DELFNO:Running: FNO, noise_level=0.1, seed=108
# 21:32:11 | INFO | Epoch  100/500: loss=0.022895
# INFO:DELFNO:Epoch  100/500: loss=0.022895
# 21:33:51 | INFO | Epoch  200/500: loss=0.014366
# INFO:DELFNO:Epoch  200/500: loss=0.014366
# 21:35:33 | INFO | Epoch  300/500: loss=0.007614
# INFO:DELFNO:Epoch  300/500: loss=0.007614
# 21:37:13 | INFO | Epoch  400/500: loss=0.003461
# INFO:DELFNO:Epoch  400/500: loss=0.003461
# 21:38:53 | INFO | Epoch  500/500: loss=0.002144
# INFO:DELFNO:Epoch  500/500: loss=0.002144
# 21:38:53 | INFO |   Result: test_err=0.008986, train_err=0.002160, time=501.3s
# INFO:DELFNO:  Result: test_err=0.008986, train_err=0.002160, time=501.3s
# 21:38:53 | INFO | Running: FNO, noise_level=0.1, seed=888
# INFO:DELFNO:Running: FNO, noise_level=0.1, seed=888
# 21:40:33 | INFO | Epoch  100/500: loss=0.025390
# INFO:DELFNO:Epoch  100/500: loss=0.025390
# 21:42:12 | INFO | Epoch  200/500: loss=0.014812
# INFO:DELFNO:Epoch  200/500: loss=0.014812
# 21:43:51 | INFO | Epoch  300/500: loss=0.008039
# INFO:DELFNO:Epoch  300/500: loss=0.008039
# 21:45:30 | INFO | Epoch  400/500: loss=0.003191
# INFO:DELFNO:Epoch  400/500: loss=0.003191
# 21:47:10 | INFO | Epoch  500/500: loss=0.001901
# INFO:DELFNO:Epoch  500/500: loss=0.001901
# 21:47:10 | INFO |   Result: test_err=0.009095, train_err=0.001923, time=496.7s
# INFO:DELFNO:  Result: test_err=0.009095, train_err=0.001923, time=496.7s
# 21:47:10 | INFO | Running: DEL-FNO, noise_level=0.1, seed=42
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.1, seed=42
# 21:49:45 | INFO | Epoch  100/500: loss=0.023818, β=[0.5689, 3.1715], scale=[1.3724, 0.3958]
# INFO:DELFNO:Epoch  100/500: loss=0.023818, β=[0.5689, 3.1715], scale=[1.3724, 0.3958]
# 21:52:20 | INFO | Epoch  200/500: loss=0.015389, β=[0.5751, 2.0703], scale=[0.7410, 1.4214]
# INFO:DELFNO:Epoch  200/500: loss=0.015389, β=[0.5751, 2.0703], scale=[0.7410, 1.4214]
# 21:54:56 | INFO | Epoch  300/500: loss=0.008524, β=[0.5771, 2.1329], scale=[0.6419, 2.3012]
# INFO:DELFNO:Epoch  300/500: loss=0.008524, β=[0.5771, 2.1329], scale=[0.6419, 2.3012]
# 21:57:33 | INFO | Epoch  400/500: loss=0.003531, β=[0.5429, 2.1055], scale=[0.8227, 2.5389]
# INFO:DELFNO:Epoch  400/500: loss=0.003531, β=[0.5429, 2.1055], scale=[0.8227, 2.5389]
# 22:00:08 | INFO | Epoch  500/500: loss=0.002208, β=[0.5291, 2.0943], scale=[0.8716, 2.5853]
# INFO:DELFNO:Epoch  500/500: loss=0.002208, β=[0.5291, 2.0943], scale=[0.8716, 2.5853]
# 22:00:08 | INFO |   Result: test_err=0.007322, train_err=0.002222, time=778.3s
# INFO:DELFNO:  Result: test_err=0.007322, train_err=0.002222, time=778.3s
# 22:00:08 | INFO |   Final β: [0.5290957689285278, 2.0943355560302734]
# INFO:DELFNO:  Final β: [0.5290957689285278, 2.0943355560302734]
# 22:00:08 | INFO | Running: DEL-FNO, noise_level=0.1, seed=108
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.1, seed=108
# 22:02:44 | INFO | Epoch  100/500: loss=0.023418, β=[0.5236, 1.7538], scale=[1.3905, 1.0468]
# INFO:DELFNO:Epoch  100/500: loss=0.023418, β=[0.5236, 1.7538], scale=[1.3905, 1.0468]
# 22:05:20 | INFO | Epoch  200/500: loss=0.013672, β=[0.5186, 2.2896], scale=[0.6434, 1.7456]
# INFO:DELFNO:Epoch  200/500: loss=0.013672, β=[0.5186, 2.2896], scale=[0.6434, 1.7456]
# 22:07:56 | INFO | Epoch  300/500: loss=0.008443, β=[0.6071, 2.0680], scale=[0.4410, 2.0598]
# INFO:DELFNO:Epoch  300/500: loss=0.008443, β=[0.6071, 2.0680], scale=[0.4410, 2.0598]
# 22:10:31 | INFO | Epoch  400/500: loss=0.002641, β=[0.6269, 2.1305], scale=[0.5370, 2.1930]
# INFO:DELFNO:Epoch  400/500: loss=0.002641, β=[0.6269, 2.1305], scale=[0.5370, 2.1930]
# 22:13:08 | INFO | Epoch  500/500: loss=0.001530, β=[0.6307, 2.1286], scale=[0.5785, 2.2135]
# INFO:DELFNO:Epoch  500/500: loss=0.001530, β=[0.6307, 2.1286], scale=[0.5785, 2.2135]
# 22:13:08 | INFO |   Result: test_err=0.006643, train_err=0.001553, time=779.3s
# INFO:DELFNO:  Result: test_err=0.006643, train_err=0.001553, time=779.3s
# 22:13:08 | INFO |   Final β: [0.6306713223457336, 2.1285955905914307]
# INFO:DELFNO:  Final β: [0.6306713223457336, 2.1285955905914307]
# 22:13:08 | INFO | Running: DEL-FNO, noise_level=0.1, seed=888
# INFO:DELFNO:Running: DEL-FNO, noise_level=0.1, seed=888
# 22:15:44 | INFO | Epoch  100/500: loss=0.027897, β=[1.3273, 1.7218], scale=[0.7405, 1.3886]
# INFO:DELFNO:Epoch  100/500: loss=0.027897, β=[1.3273, 1.7218], scale=[0.7405, 1.3886]
# 22:18:19 | INFO | Epoch  200/500: loss=0.015494, β=[1.3381, 2.0897], scale=[0.0000, 2.1105]
# INFO:DELFNO:Epoch  200/500: loss=0.015494, β=[1.3381, 2.0897], scale=[0.0000, 2.1105]
# 22:20:55 | INFO | Epoch  300/500: loss=0.007787, β=[1.3381, 2.1842], scale=[0.0000, 2.5674]
# INFO:DELFNO:Epoch  300/500: loss=0.007787, β=[1.3381, 2.1842], scale=[0.0000, 2.5674]
# 22:23:30 | INFO | Epoch  400/500: loss=0.003182, β=[1.3381, 2.1024], scale=[0.0000, 2.7384]
# INFO:DELFNO:Epoch  400/500: loss=0.003182, β=[1.3381, 2.1024], scale=[0.0000, 2.7384]
# 22:26:05 | INFO | Epoch  500/500: loss=0.001548, β=[1.3381, 2.1093], scale=[0.0000, 2.7718]
# INFO:DELFNO:Epoch  500/500: loss=0.001548, β=[1.3381, 2.1093], scale=[0.0000, 2.7718]
# 22:26:05 | INFO |   Result: test_err=0.006928, train_err=0.001587, time=777.0s
# INFO:DELFNO:  Result: test_err=0.006928, train_err=0.001587, time=777.0s
# 22:26:05 | INFO |   Final β: [1.3380733728408813, 2.10927152633667]
# INFO:DELFNO:  Final β: [1.3380733728408813, 2.10927152633667]
# 22:26:05 | INFO | Results saved to ./results/exp1_noise_robustness_r10.csv
# INFO:DELFNO:Results saved to ./results/exp1_noise_robustness_r10.csv
# 22:26:05 | INFO | Experiment 1 complete! Shape: (30, 14)
# INFO:DELFNO:Experiment 1 complete! Shape: (30, 14)

# %%
# @title Cell 12: Experiment 2 - Sample Efficiency
log.info("="*60)
log.info("EXPERIMENT 2: SAMPLE EFFICIENCY")
log.info("="*60)

df_sample = run_experiment_grid(
    experiment_name='exp2_sample_efficiency',
    variable_name='n_train',
    variable_values=cfg.sample_sizes,
    cfg=cfg,
    fixed_params={'noise_level': 0.0, 'modes': cfg.modes}
)

log.info(f"Experiment 2 complete! Shape: {df_sample.shape}")
# Out:
# 22:26:05 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 22:26:05 | INFO | EXPERIMENT 2: SAMPLE EFFICIENCY
# INFO:DELFNO:EXPERIMENT 2: SAMPLE EFFICIENCY
# 22:26:05 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 22:26:05 | INFO | Loading r10 data...
# INFO:DELFNO:Loading r10 data...
# 22:26:05 | INFO | Loading: ./data/burgers_r10.mat (644.4MB)
# INFO:DELFNO:Loading: ./data/burgers_r10.mat (644.4MB)
# 22:26:09 | INFO |   scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# INFO:DELFNO:  scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# 22:26:09 | INFO |   Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# INFO:DELFNO:  Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# 22:26:09 | INFO |   Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# INFO:DELFNO:  Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# 22:26:09 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 22:26:09 | INFO | Experiment: exp2_sample_efficiency
# INFO:DELFNO:Experiment: exp2_sample_efficiency
# 22:26:09 | INFO | Dataset: r10
# INFO:DELFNO:Dataset: r10
# 22:26:09 | INFO | Variable: n_train = [125, 250, 500, 1000]
# INFO:DELFNO:Variable: n_train = [125, 250, 500, 1000]
# 22:26:09 | INFO | Seeds: [42, 108, 888]
# INFO:DELFNO:Seeds: [42, 108, 888]
# 22:26:09 | INFO | Total runs: 24
# INFO:DELFNO:Total runs: 24
# 22:26:09 | INFO | ============================================================
# INFO:DELFNO:============================================================
# exp2_sample_efficiency:   0%|          | 0/24 [00:00<?, ?it/s]
# 22:26:09 | INFO | Running: FNO, n_train=125, seed=42
# INFO:DELFNO:Running: FNO, n_train=125, seed=42
# 22:26:21 | INFO | Epoch  100/500: loss=0.021890
# INFO:DELFNO:Epoch  100/500: loss=0.021890
# 22:26:33 | INFO | Epoch  200/500: loss=0.025041
# INFO:DELFNO:Epoch  200/500: loss=0.025041
# 22:26:45 | INFO | Epoch  300/500: loss=0.018658
# INFO:DELFNO:Epoch  300/500: loss=0.018658
# 22:26:57 | INFO | Epoch  400/500: loss=0.004032
# INFO:DELFNO:Epoch  400/500: loss=0.004032
# 22:27:09 | INFO | Epoch  500/500: loss=0.001635
# INFO:DELFNO:Epoch  500/500: loss=0.001635
# 22:27:09 | INFO |   Result: test_err=0.003377, train_err=0.001654, time=60.0s
# INFO:DELFNO:  Result: test_err=0.003377, train_err=0.001654, time=60.0s
# 22:27:09 | INFO | Running: FNO, n_train=125, seed=108
# INFO:DELFNO:Running: FNO, n_train=125, seed=108
# 22:27:21 | INFO | Epoch  100/500: loss=0.029335
# INFO:DELFNO:Epoch  100/500: loss=0.029335
# 22:27:33 | INFO | Epoch  200/500: loss=0.021415
# INFO:DELFNO:Epoch  200/500: loss=0.021415
# 22:27:45 | INFO | Epoch  300/500: loss=0.014258
# INFO:DELFNO:Epoch  300/500: loss=0.014258
# 22:27:57 | INFO | Epoch  400/500: loss=0.003535
# INFO:DELFNO:Epoch  400/500: loss=0.003535
# 22:28:09 | INFO | Epoch  500/500: loss=0.001589
# INFO:DELFNO:Epoch  500/500: loss=0.001589
# 22:28:09 | INFO |   Result: test_err=0.003395, train_err=0.001601, time=59.7s
# INFO:DELFNO:  Result: test_err=0.003395, train_err=0.001601, time=59.7s
# 22:28:09 | INFO | Running: FNO, n_train=125, seed=888
# INFO:DELFNO:Running: FNO, n_train=125, seed=888
# 22:28:21 | INFO | Epoch  100/500: loss=0.039711
# INFO:DELFNO:Epoch  100/500: loss=0.039711
# 22:28:33 | INFO | Epoch  200/500: loss=0.023452
# INFO:DELFNO:Epoch  200/500: loss=0.023452
# 22:28:45 | INFO | Epoch  300/500: loss=0.011082
# INFO:DELFNO:Epoch  300/500: loss=0.011082
# 22:28:57 | INFO | Epoch  400/500: loss=0.003137
# INFO:DELFNO:Epoch  400/500: loss=0.003137
# 22:29:09 | INFO | Epoch  500/500: loss=0.001780
# INFO:DELFNO:Epoch  500/500: loss=0.001780
# 22:29:09 | INFO |   Result: test_err=0.003577, train_err=0.001809, time=59.8s
# INFO:DELFNO:  Result: test_err=0.003577, train_err=0.001809, time=59.8s
# 22:29:09 | INFO | Running: DEL-FNO, n_train=125, seed=42
# INFO:DELFNO:Running: DEL-FNO, n_train=125, seed=42
# 22:29:27 | INFO | Epoch  100/500: loss=0.038808, β=[0.9123, 2.1132], scale=[0.8192, 0.3694]
# INFO:DELFNO:Epoch  100/500: loss=0.038808, β=[0.9123, 2.1132], scale=[0.8192, 0.3694]
# 22:29:46 | INFO | Epoch  200/500: loss=0.020073, β=[0.9247, 2.0744], scale=[0.4989, 0.0824]
# INFO:DELFNO:Epoch  200/500: loss=0.020073, β=[0.9247, 2.0744], scale=[0.4989, 0.0824]
# 22:30:05 | INFO | Epoch  300/500: loss=0.012460, β=[0.8859, 2.0155], scale=[0.4351, 0.0703]
# INFO:DELFNO:Epoch  300/500: loss=0.012460, β=[0.8859, 2.0155], scale=[0.4351, 0.0703]
# 22:30:23 | INFO | Epoch  400/500: loss=0.003513, β=[0.8807, 1.9611], scale=[0.3630, 0.0749]
# INFO:DELFNO:Epoch  400/500: loss=0.003513, β=[0.8807, 1.9611], scale=[0.3630, 0.0749]
# 22:30:42 | INFO | Epoch  500/500: loss=0.001767, β=[0.8663, 1.9310], scale=[0.3533, 0.0737]
# INFO:DELFNO:Epoch  500/500: loss=0.001767, β=[0.8663, 1.9310], scale=[0.3533, 0.0737]
# 22:30:42 | INFO |   Result: test_err=0.003424, train_err=0.001764, time=93.1s
# INFO:DELFNO:  Result: test_err=0.003424, train_err=0.001764, time=93.1s
# 22:30:42 | INFO |   Final β: [0.8662576675415039, 1.9310048818588257]
# INFO:DELFNO:  Final β: [0.8662576675415039, 1.9310048818588257]
# 22:30:42 | INFO | Running: DEL-FNO, n_train=125, seed=108
# INFO:DELFNO:Running: DEL-FNO, n_train=125, seed=108
# 22:31:01 | INFO | Epoch  100/500: loss=0.040063, β=[0.9746, 1.8859], scale=[0.8685, 0.6161]
# INFO:DELFNO:Epoch  100/500: loss=0.040063, β=[0.9746, 1.8859], scale=[0.8685, 0.6161]
# 22:31:20 | INFO | Epoch  200/500: loss=0.022341, β=[1.0297, 1.8635], scale=[0.7627, 0.6714]
# INFO:DELFNO:Epoch  200/500: loss=0.022341, β=[1.0297, 1.8635], scale=[0.7627, 0.6714]
# 22:31:38 | INFO | Epoch  300/500: loss=0.009165, β=[1.0728, 1.7882], scale=[0.6989, 0.5714]
# INFO:DELFNO:Epoch  300/500: loss=0.009165, β=[1.0728, 1.7882], scale=[0.6989, 0.5714]
# 22:31:57 | INFO | Epoch  400/500: loss=0.003843, β=[1.0847, 1.7066], scale=[0.6720, 0.5657]
# INFO:DELFNO:Epoch  400/500: loss=0.003843, β=[1.0847, 1.7066], scale=[0.6720, 0.5657]
# 22:32:16 | INFO | Epoch  500/500: loss=0.001748, β=[1.0878, 1.6771], scale=[0.6634, 0.5879]
# INFO:DELFNO:Epoch  500/500: loss=0.001748, β=[1.0878, 1.6771], scale=[0.6634, 0.5879]
# 22:32:16 | INFO |   Result: test_err=0.003553, train_err=0.001769, time=94.3s
# INFO:DELFNO:  Result: test_err=0.003553, train_err=0.001769, time=94.3s
# 22:32:16 | INFO |   Final β: [1.0877546072006226, 1.6770782470703125]
# INFO:DELFNO:  Final β: [1.0877546072006226, 1.6770782470703125]
# 22:32:16 | INFO | Running: DEL-FNO, n_train=125, seed=888
# INFO:DELFNO:Running: DEL-FNO, n_train=125, seed=888
# 22:32:35 | INFO | Epoch  100/500: loss=0.036713, β=[1.1069, 2.1083], scale=[0.8413, 1.5577]
# INFO:DELFNO:Epoch  100/500: loss=0.036713, β=[1.1069, 2.1083], scale=[0.8413, 1.5577]
# 22:32:54 | INFO | Epoch  200/500: loss=0.024333, β=[1.1709, 2.1435], scale=[0.7321, 1.3444]
# INFO:DELFNO:Epoch  200/500: loss=0.024333, β=[1.1709, 2.1435], scale=[0.7321, 1.3444]
# 22:33:13 | INFO | Epoch  300/500: loss=0.013157, β=[1.2307, 2.3634], scale=[0.6239, 1.0199]
# INFO:DELFNO:Epoch  300/500: loss=0.013157, β=[1.2307, 2.3634], scale=[0.6239, 1.0199]
# 22:33:32 | INFO | Epoch  400/500: loss=0.003598, β=[1.2692, 2.3680], scale=[0.5624, 0.8605]
# INFO:DELFNO:Epoch  400/500: loss=0.003598, β=[1.2692, 2.3680], scale=[0.5624, 0.8605]
# 22:33:50 | INFO | Epoch  500/500: loss=0.001793, β=[1.2874, 2.3792], scale=[0.5417, 0.8310]
# INFO:DELFNO:Epoch  500/500: loss=0.001793, β=[1.2874, 2.3792], scale=[0.5417, 0.8310]
# 22:33:50 | INFO |   Result: test_err=0.003548, train_err=0.001798, time=94.0s
# INFO:DELFNO:  Result: test_err=0.003548, train_err=0.001798, time=94.0s
# 22:33:50 | INFO |   Final β: [1.2874234914779663, 2.379169225692749]
# INFO:DELFNO:  Final β: [1.2874234914779663, 2.379169225692749]
# 22:33:50 | INFO | Running: FNO, n_train=250, seed=42
# INFO:DELFNO:Running: FNO, n_train=250, seed=42
# 22:34:15 | INFO | Epoch  100/500: loss=0.039756
# INFO:DELFNO:Epoch  100/500: loss=0.039756
# 22:34:40 | INFO | Epoch  200/500: loss=0.024066
# INFO:DELFNO:Epoch  200/500: loss=0.024066
# 22:35:05 | INFO | Epoch  300/500: loss=0.010747
# INFO:DELFNO:Epoch  300/500: loss=0.010747
# 22:35:30 | INFO | Epoch  400/500: loss=0.003182
# INFO:DELFNO:Epoch  400/500: loss=0.003182
# 22:35:55 | INFO | Epoch  500/500: loss=0.000614
# INFO:DELFNO:Epoch  500/500: loss=0.000614
# 22:35:55 | INFO |   Result: test_err=0.001548, train_err=0.000669, time=124.7s
# INFO:DELFNO:  Result: test_err=0.001548, train_err=0.000669, time=124.7s
# 22:35:55 | INFO | Running: FNO, n_train=250, seed=108
# INFO:DELFNO:Running: FNO, n_train=250, seed=108
# 22:36:20 | INFO | Epoch  100/500: loss=0.029122
# INFO:DELFNO:Epoch  100/500: loss=0.029122
# 22:36:45 | INFO | Epoch  200/500: loss=0.023212
# INFO:DELFNO:Epoch  200/500: loss=0.023212
# 22:37:10 | INFO | Epoch  300/500: loss=0.012423
# INFO:DELFNO:Epoch  300/500: loss=0.012423
# 22:37:35 | INFO | Epoch  400/500: loss=0.002588
# INFO:DELFNO:Epoch  400/500: loss=0.002588
# 22:38:00 | INFO | Epoch  500/500: loss=0.000650
# INFO:DELFNO:Epoch  500/500: loss=0.000650
# 22:38:00 | INFO |   Result: test_err=0.001553, train_err=0.000693, time=124.5s
# INFO:DELFNO:  Result: test_err=0.001553, train_err=0.000693, time=124.5s
# 22:38:00 | INFO | Running: FNO, n_train=250, seed=888
# INFO:DELFNO:Running: FNO, n_train=250, seed=888
# 22:38:25 | INFO | Epoch  100/500: loss=0.035145
# INFO:DELFNO:Epoch  100/500: loss=0.035145
# 22:38:50 | INFO | Epoch  200/500: loss=0.016870
# INFO:DELFNO:Epoch  200/500: loss=0.016870
# 22:39:15 | INFO | Epoch  300/500: loss=0.008975
# INFO:DELFNO:Epoch  300/500: loss=0.008975
# 22:39:40 | INFO | Epoch  400/500: loss=0.002905
# INFO:DELFNO:Epoch  400/500: loss=0.002905
# 22:40:06 | INFO | Epoch  500/500: loss=0.000627
# INFO:DELFNO:Epoch  500/500: loss=0.000627
# 22:40:06 | INFO |   Result: test_err=0.001564, train_err=0.000669, time=125.9s
# INFO:DELFNO:  Result: test_err=0.001564, train_err=0.000669, time=125.9s
# 22:40:06 | INFO | Running: DEL-FNO, n_train=250, seed=42
# INFO:DELFNO:Running: DEL-FNO, n_train=250, seed=42
# 22:40:45 | INFO | Epoch  100/500: loss=0.037803, β=[0.9439, 2.0274], scale=[0.6044, 0.0210]
# INFO:DELFNO:Epoch  100/500: loss=0.037803, β=[0.9439, 2.0274], scale=[0.6044, 0.0210]
# 22:41:23 | INFO | Epoch  200/500: loss=0.021401, β=[0.9745, 2.0207], scale=[0.2358, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.021401, β=[0.9745, 2.0207], scale=[0.2358, 0.0000]
# 22:42:01 | INFO | Epoch  300/500: loss=0.008768, β=[1.0212, 2.0207], scale=[0.1312, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.008768, β=[1.0212, 2.0207], scale=[0.1312, 0.0000]
# 22:42:40 | INFO | Epoch  400/500: loss=0.002528, β=[1.0532, 2.0207], scale=[0.1024, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.002528, β=[1.0532, 2.0207], scale=[0.1024, 0.0000]
# 22:43:19 | INFO | Epoch  500/500: loss=0.000665, β=[1.0497, 2.0207], scale=[0.1055, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000665, β=[1.0497, 2.0207], scale=[0.1055, 0.0000]
# 22:43:19 | INFO |   Result: test_err=0.001504, train_err=0.000691, time=193.0s
# INFO:DELFNO:  Result: test_err=0.001504, train_err=0.000691, time=193.0s
# 22:43:19 | INFO |   Final β: [1.0497392416000366, 2.0206727981567383]
# INFO:DELFNO:  Final β: [1.0497392416000366, 2.0206727981567383]
# 22:43:19 | INFO | Running: DEL-FNO, n_train=250, seed=108
# INFO:DELFNO:Running: DEL-FNO, n_train=250, seed=108
# 22:43:57 | INFO | Epoch  100/500: loss=0.026131, β=[1.0328, 1.9413], scale=[0.7908, 0.8364]
# INFO:DELFNO:Epoch  100/500: loss=0.026131, β=[1.0328, 1.9413], scale=[0.7908, 0.8364]
# 22:44:35 | INFO | Epoch  200/500: loss=0.020128, β=[1.2387, 2.0678], scale=[0.5876, 0.7470]
# INFO:DELFNO:Epoch  200/500: loss=0.020128, β=[1.2387, 2.0678], scale=[0.5876, 0.7470]
# 22:45:13 | INFO | Epoch  300/500: loss=0.010190, β=[1.3888, 1.9207], scale=[0.4287, 0.4968]
# INFO:DELFNO:Epoch  300/500: loss=0.010190, β=[1.3888, 1.9207], scale=[0.4287, 0.4968]
# 22:45:51 | INFO | Epoch  400/500: loss=0.002306, β=[1.4250, 1.8966], scale=[0.3757, 0.4147]
# INFO:DELFNO:Epoch  400/500: loss=0.002306, β=[1.4250, 1.8966], scale=[0.3757, 0.4147]
# 22:46:29 | INFO | Epoch  500/500: loss=0.000634, β=[1.4307, 1.9119], scale=[0.3630, 0.4450]
# INFO:DELFNO:Epoch  500/500: loss=0.000634, β=[1.4307, 1.9119], scale=[0.3630, 0.4450]
# 22:46:29 | INFO |   Result: test_err=0.001487, train_err=0.000676, time=190.9s
# INFO:DELFNO:  Result: test_err=0.001487, train_err=0.000676, time=190.9s
# 22:46:29 | INFO |   Final β: [1.4307024478912354, 1.9118648767471313]
# INFO:DELFNO:  Final β: [1.4307024478912354, 1.9118648767471313]
# 22:46:29 | INFO | Running: DEL-FNO, n_train=250, seed=888
# INFO:DELFNO:Running: DEL-FNO, n_train=250, seed=888
# 22:47:08 | INFO | Epoch  100/500: loss=0.041973, β=[0.9454, 2.1476], scale=[0.8287, 1.5371]
# INFO:DELFNO:Epoch  100/500: loss=0.041973, β=[0.9454, 2.1476], scale=[0.8287, 1.5371]
# 22:47:46 | INFO | Epoch  200/500: loss=0.020760, β=[1.0503, 2.0879], scale=[0.5932, 0.9740]
# INFO:DELFNO:Epoch  200/500: loss=0.020760, β=[1.0503, 2.0879], scale=[0.5932, 0.9740]
# 22:48:24 | INFO | Epoch  300/500: loss=0.008345, β=[1.1401, 1.9599], scale=[0.4318, 0.5272]
# INFO:DELFNO:Epoch  300/500: loss=0.008345, β=[1.1401, 1.9599], scale=[0.4318, 0.5272]
# 22:49:02 | INFO | Epoch  400/500: loss=0.002340, β=[1.1691, 1.9654], scale=[0.3885, 0.4987]
# INFO:DELFNO:Epoch  400/500: loss=0.002340, β=[1.1691, 1.9654], scale=[0.3885, 0.4987]
# 22:49:40 | INFO | Epoch  500/500: loss=0.000647, β=[1.1717, 1.9992], scale=[0.3893, 0.5481]
# INFO:DELFNO:Epoch  500/500: loss=0.000647, β=[1.1717, 1.9992], scale=[0.3893, 0.5481]
# 22:49:40 | INFO |   Result: test_err=0.001481, train_err=0.000709, time=190.2s
# INFO:DELFNO:  Result: test_err=0.001481, train_err=0.000709, time=190.2s
# 22:49:40 | INFO |   Final β: [1.171722650527954, 1.9991791248321533]
# INFO:DELFNO:  Final β: [1.171722650527954, 1.9991791248321533]
# 22:49:40 | INFO | Running: FNO, n_train=500, seed=42
# INFO:DELFNO:Running: FNO, n_train=500, seed=42
# 22:50:29 | INFO | Epoch  100/500: loss=0.036141
# INFO:DELFNO:Epoch  100/500: loss=0.036141
# 22:51:18 | INFO | Epoch  200/500: loss=0.013991
# INFO:DELFNO:Epoch  200/500: loss=0.013991
# 22:52:07 | INFO | Epoch  300/500: loss=0.006463
# INFO:DELFNO:Epoch  300/500: loss=0.006463
# 22:52:56 | INFO | Epoch  400/500: loss=0.001873
# INFO:DELFNO:Epoch  400/500: loss=0.001873
# 22:53:45 | INFO | Epoch  500/500: loss=0.000411
# INFO:DELFNO:Epoch  500/500: loss=0.000411
# 22:53:45 | INFO |   Result: test_err=0.001140, train_err=0.000511, time=244.9s
# INFO:DELFNO:  Result: test_err=0.001140, train_err=0.000511, time=244.9s
# 22:53:45 | INFO | Running: FNO, n_train=500, seed=108
# INFO:DELFNO:Running: FNO, n_train=500, seed=108
# 22:54:34 | INFO | Epoch  100/500: loss=0.034592
# INFO:DELFNO:Epoch  100/500: loss=0.034592
# 22:55:23 | INFO | Epoch  200/500: loss=0.017851
# INFO:DELFNO:Epoch  200/500: loss=0.017851
# 22:56:11 | INFO | Epoch  300/500: loss=0.007270
# INFO:DELFNO:Epoch  300/500: loss=0.007270
# 22:57:00 | INFO | Epoch  400/500: loss=0.002453
# INFO:DELFNO:Epoch  400/500: loss=0.002453
# 22:57:49 | INFO | Epoch  500/500: loss=0.000467
# INFO:DELFNO:Epoch  500/500: loss=0.000467
# 22:57:49 | INFO |   Result: test_err=0.001122, train_err=0.000575, time=244.2s
# INFO:DELFNO:  Result: test_err=0.001122, train_err=0.000575, time=244.2s
# 22:57:49 | INFO | Running: FNO, n_train=500, seed=888
# INFO:DELFNO:Running: FNO, n_train=500, seed=888
# 22:58:38 | INFO | Epoch  100/500: loss=0.028440
# INFO:DELFNO:Epoch  100/500: loss=0.028440
# 22:59:27 | INFO | Epoch  200/500: loss=0.012912
# INFO:DELFNO:Epoch  200/500: loss=0.012912
# 23:00:16 | INFO | Epoch  300/500: loss=0.006189
# INFO:DELFNO:Epoch  300/500: loss=0.006189
# 23:01:05 | INFO | Epoch  400/500: loss=0.001817
# INFO:DELFNO:Epoch  400/500: loss=0.001817
# 23:01:54 | INFO | Epoch  500/500: loss=0.000421
# INFO:DELFNO:Epoch  500/500: loss=0.000421
# 23:01:54 | INFO |   Result: test_err=0.001108, train_err=0.000520, time=245.2s
# INFO:DELFNO:  Result: test_err=0.001108, train_err=0.000520, time=245.2s
# 23:01:54 | INFO | Running: DEL-FNO, n_train=500, seed=42
# INFO:DELFNO:Running: DEL-FNO, n_train=500, seed=42
# 23:03:10 | INFO | Epoch  100/500: loss=0.022161, β=[1.0211, 2.0116], scale=[0.3564, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.022161, β=[1.0211, 2.0116], scale=[0.3564, 0.0000]
# 23:04:26 | INFO | Epoch  200/500: loss=0.018728, β=[1.2483, 2.0116], scale=[0.0327, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.018728, β=[1.2483, 2.0116], scale=[0.0327, 0.0000]
# 23:05:43 | INFO | Epoch  300/500: loss=0.010121, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.010121, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# 23:07:00 | INFO | Epoch  400/500: loss=0.001735, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001735, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# 23:08:16 | INFO | Epoch  500/500: loss=0.000422, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000422, β=[1.2985, 2.0116], scale=[0.0000, 0.0000]
# 23:08:16 | INFO |   Result: test_err=0.000991, train_err=0.000470, time=381.8s
# INFO:DELFNO:  Result: test_err=0.000991, train_err=0.000470, time=381.8s
# 23:08:16 | INFO |   Final β: [1.2985299825668335, 2.0116398334503174]
# INFO:DELFNO:  Final β: [1.2985299825668335, 2.0116398334503174]
# 23:08:16 | INFO | Running: DEL-FNO, n_train=500, seed=108
# INFO:DELFNO:Running: DEL-FNO, n_train=500, seed=108
# 23:09:32 | INFO | Epoch  100/500: loss=0.029716, β=[1.2100, 1.9372], scale=[0.6183, 0.2632]
# INFO:DELFNO:Epoch  100/500: loss=0.029716, β=[1.2100, 1.9372], scale=[0.6183, 0.2632]
# 23:10:48 | INFO | Epoch  200/500: loss=0.015950, β=[1.5422, 1.8962], scale=[0.2729, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.015950, β=[1.5422, 1.8962], scale=[0.2729, 0.0000]
# 23:12:04 | INFO | Epoch  300/500: loss=0.005677, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005677, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# 23:13:21 | INFO | Epoch  400/500: loss=0.002085, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.002085, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# 23:14:37 | INFO | Epoch  500/500: loss=0.000424, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000424, β=[1.5291, 1.8962], scale=[0.0000, 0.0000]
# 23:14:37 | INFO |   Result: test_err=0.001050, train_err=0.000536, time=380.8s
# INFO:DELFNO:  Result: test_err=0.001050, train_err=0.000536, time=380.8s
# 23:14:37 | INFO |   Final β: [1.5291236639022827, 1.896204948425293]
# INFO:DELFNO:  Final β: [1.5291236639022827, 1.896204948425293]
# 23:14:37 | INFO | Running: DEL-FNO, n_train=500, seed=888
# INFO:DELFNO:Running: DEL-FNO, n_train=500, seed=888
# 23:15:53 | INFO | Epoch  100/500: loss=0.025150, β=[1.1251, 4.4197], scale=[0.5743, 0.5670]
# INFO:DELFNO:Epoch  100/500: loss=0.025150, β=[1.1251, 4.4197], scale=[0.5743, 0.5670]
# 23:17:09 | INFO | Epoch  200/500: loss=0.010389, β=[1.3348, 4.4004], scale=[0.0608, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.010389, β=[1.3348, 4.4004], scale=[0.0608, 0.0000]
# 23:18:25 | INFO | Epoch  300/500: loss=0.007586, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.007586, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# 23:19:42 | INFO | Epoch  400/500: loss=0.001614, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001614, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# 23:20:58 | INFO | Epoch  500/500: loss=0.000438, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000438, β=[1.3533, 4.4004], scale=[0.0000, 0.0000]
# 23:20:58 | INFO |   Result: test_err=0.001080, train_err=0.000517, time=381.0s
# INFO:DELFNO:  Result: test_err=0.001080, train_err=0.000517, time=381.0s
# 23:20:58 | INFO |   Final β: [1.3532533645629883, 4.400391101837158]
# INFO:DELFNO:  Final β: [1.3532533645629883, 4.400391101837158]
# 23:20:58 | INFO | Running: FNO, n_train=1000, seed=42
# INFO:DELFNO:Running: FNO, n_train=1000, seed=42
# 23:22:37 | INFO | Epoch  100/500: loss=0.020332
# INFO:DELFNO:Epoch  100/500: loss=0.020332
# 23:24:15 | INFO | Epoch  200/500: loss=0.013341
# INFO:DELFNO:Epoch  200/500: loss=0.013341
# 23:25:54 | INFO | Epoch  300/500: loss=0.005252
# INFO:DELFNO:Epoch  300/500: loss=0.005252
# 23:27:32 | INFO | Epoch  400/500: loss=0.001376
# INFO:DELFNO:Epoch  400/500: loss=0.001376
# 23:29:11 | INFO | Epoch  500/500: loss=0.000333
# INFO:DELFNO:Epoch  500/500: loss=0.000333
# 23:29:11 | INFO |   Result: test_err=0.000852, train_err=0.000565, time=493.1s
# INFO:DELFNO:  Result: test_err=0.000852, train_err=0.000565, time=493.1s
# 23:29:11 | INFO | Running: FNO, n_train=1000, seed=108
# INFO:DELFNO:Running: FNO, n_train=1000, seed=108
# 23:30:50 | INFO | Epoch  100/500: loss=0.020790
# INFO:DELFNO:Epoch  100/500: loss=0.020790
# 23:32:29 | INFO | Epoch  200/500: loss=0.010817
# INFO:DELFNO:Epoch  200/500: loss=0.010817
# 23:34:07 | INFO | Epoch  300/500: loss=0.005295
# INFO:DELFNO:Epoch  300/500: loss=0.005295
# 23:35:46 | INFO | Epoch  400/500: loss=0.001502
# INFO:DELFNO:Epoch  400/500: loss=0.001502
# 23:37:25 | INFO | Epoch  500/500: loss=0.000325
# INFO:DELFNO:Epoch  500/500: loss=0.000325
# 23:37:25 | INFO |   Result: test_err=0.000759, train_err=0.000515, time=493.8s
# INFO:DELFNO:  Result: test_err=0.000759, train_err=0.000515, time=493.8s
# 23:37:25 | INFO | Running: FNO, n_train=1000, seed=888
# INFO:DELFNO:Running: FNO, n_train=1000, seed=888
# 23:39:04 | INFO | Epoch  100/500: loss=0.025433
# INFO:DELFNO:Epoch  100/500: loss=0.025433
# 23:40:43 | INFO | Epoch  200/500: loss=0.010580
# INFO:DELFNO:Epoch  200/500: loss=0.010580
# 23:42:21 | INFO | Epoch  300/500: loss=0.004750
# INFO:DELFNO:Epoch  300/500: loss=0.004750
# 23:44:00 | INFO | Epoch  400/500: loss=0.001337
# INFO:DELFNO:Epoch  400/500: loss=0.001337
# 23:45:39 | INFO | Epoch  500/500: loss=0.000304
# INFO:DELFNO:Epoch  500/500: loss=0.000304
# 23:45:39 | INFO |   Result: test_err=0.000744, train_err=0.000447, time=493.7s
# INFO:DELFNO:  Result: test_err=0.000744, train_err=0.000447, time=493.7s
# 23:45:39 | INFO | Running: DEL-FNO, n_train=1000, seed=42
# INFO:DELFNO:Running: DEL-FNO, n_train=1000, seed=42
# 23:48:12 | INFO | Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# 23:50:46 | INFO | Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 23:53:19 | INFO | Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 23:55:52 | INFO | Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 23:58:26 | INFO | Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 23:58:26 | INFO |   Result: test_err=0.000676, train_err=0.000436, time=767.3s
# INFO:DELFNO:  Result: test_err=0.000676, train_err=0.000436, time=767.3s
# 23:58:26 | INFO |   Final β: [1.288582444190979, 2.3165488243103027]
# INFO:DELFNO:  Final β: [1.288582444190979, 2.3165488243103027]
# 23:58:26 | INFO | Running: DEL-FNO, n_train=1000, seed=108
# INFO:DELFNO:Running: DEL-FNO, n_train=1000, seed=108
# 00:01:00 | INFO | Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# INFO:DELFNO:Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# 00:03:34 | INFO | Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 00:06:07 | INFO | Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 00:08:40 | INFO | Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 00:11:14 | INFO | Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 00:11:14 | INFO |   Result: test_err=0.000741, train_err=0.000509, time=768.0s
# INFO:DELFNO:  Result: test_err=0.000741, train_err=0.000509, time=768.0s
# 00:11:14 | INFO |   Final β: [1.9527373313903809, 1.9374629259109497]
# INFO:DELFNO:  Final β: [1.9527373313903809, 1.9374629259109497]
# 00:11:14 | INFO | Running: DEL-FNO, n_train=1000, seed=888
# INFO:DELFNO:Running: DEL-FNO, n_train=1000, seed=888
# 00:13:48 | INFO | Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# INFO:DELFNO:Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# 00:16:21 | INFO | Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 00:18:54 | INFO | Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 00:21:27 | INFO | Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 00:24:01 | INFO | Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 00:24:01 | INFO |   Result: test_err=0.000629, train_err=0.000409, time=766.4s
# INFO:DELFNO:  Result: test_err=0.000629, train_err=0.000409, time=766.4s
# 00:24:01 | INFO |   Final β: [1.3419767618179321, 2.044556140899658]
# INFO:DELFNO:  Final β: [1.3419767618179321, 2.044556140899658]
# 00:24:01 | INFO | Results saved to ./results/exp2_sample_efficiency_r10.csv
# INFO:DELFNO:Results saved to ./results/exp2_sample_efficiency_r10.csv
# 00:24:01 | INFO | Experiment 2 complete! Shape: (24, 14)
# INFO:DELFNO:Experiment 2 complete! Shape: (24, 14)

# %%
# @title Cell 13: Experiment 3 - Modes Scaling (NEW - replaces batch size)
log.info("="*60)
log.info("EXPERIMENT 3: MODES SCALING")
log.info("="*60)

df_modes = run_experiment_grid(
    experiment_name='exp3_modes_scaling',
    variable_name='modes',
    variable_values=cfg.modes_list,
    cfg=cfg,
    fixed_params={'n_train': cfg.n_train, 'noise_level': 0.0}
)

log.info(f"Experiment 3 complete! Shape: {df_modes.shape}")
# Out:
# 00:24:01 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 00:24:01 | INFO | EXPERIMENT 3: MODES SCALING
# INFO:DELFNO:EXPERIMENT 3: MODES SCALING
# 00:24:01 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 00:24:01 | INFO | Loading r10 data...
# INFO:DELFNO:Loading r10 data...
# 00:24:01 | INFO | Loading: ./data/burgers_r10.mat (644.4MB)
# INFO:DELFNO:Loading: ./data/burgers_r10.mat (644.4MB)
# 00:24:05 | INFO |   scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# INFO:DELFNO:  scipy keys: ['a', 'a_smooth', 'a_smooth_x', 'a_x', 'u']
# 00:24:05 | INFO |   Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# INFO:DELFNO:  Shapes after loading: a=(2048, 8192), u=(2048, 8192)
# 00:24:05 | INFO |   Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# INFO:DELFNO:  Final shapes: a=torch.Size([2048, 1024]), u=torch.Size([2048, 1024])
# 00:24:05 | INFO | ============================================================
# INFO:DELFNO:============================================================
# 00:24:05 | INFO | Experiment: exp3_modes_scaling
# INFO:DELFNO:Experiment: exp3_modes_scaling
# 00:24:05 | INFO | Dataset: r10
# INFO:DELFNO:Dataset: r10
# 00:24:05 | INFO | Variable: modes = [16, 32, 64, 128]
# INFO:DELFNO:Variable: modes = [16, 32, 64, 128]
# 00:24:05 | INFO | Seeds: [42, 108, 888]
# INFO:DELFNO:Seeds: [42, 108, 888]
# 00:24:05 | INFO | Total runs: 24
# INFO:DELFNO:Total runs: 24
# 00:24:05 | INFO | ============================================================
# INFO:DELFNO:============================================================
# exp3_modes_scaling:   0%|          | 0/24 [00:00<?, ?it/s]
# 00:24:05 | INFO | Running: FNO, modes=16, seed=42
# INFO:DELFNO:Running: FNO, modes=16, seed=42
# 00:25:44 | INFO | Epoch  100/500: loss=0.020332
# INFO:DELFNO:Epoch  100/500: loss=0.020332
# 00:27:23 | INFO | Epoch  200/500: loss=0.013341
# INFO:DELFNO:Epoch  200/500: loss=0.013341
# 00:29:01 | INFO | Epoch  300/500: loss=0.005252
# INFO:DELFNO:Epoch  300/500: loss=0.005252
# 00:30:40 | INFO | Epoch  400/500: loss=0.001376
# INFO:DELFNO:Epoch  400/500: loss=0.001376
# 00:32:19 | INFO | Epoch  500/500: loss=0.000333
# INFO:DELFNO:Epoch  500/500: loss=0.000333
# 00:32:19 | INFO |   Result: test_err=0.000852, train_err=0.000565, time=494.2s
# INFO:DELFNO:  Result: test_err=0.000852, train_err=0.000565, time=494.2s
# 00:32:19 | INFO | Running: FNO, modes=16, seed=108
# INFO:DELFNO:Running: FNO, modes=16, seed=108
# 00:33:58 | INFO | Epoch  100/500: loss=0.020790
# INFO:DELFNO:Epoch  100/500: loss=0.020790
# 00:35:37 | INFO | Epoch  200/500: loss=0.010817
# INFO:DELFNO:Epoch  200/500: loss=0.010817
# 00:37:16 | INFO | Epoch  300/500: loss=0.005295
# INFO:DELFNO:Epoch  300/500: loss=0.005295
# 00:38:57 | INFO | Epoch  400/500: loss=0.001502
# INFO:DELFNO:Epoch  400/500: loss=0.001502
# 00:40:37 | INFO | Epoch  500/500: loss=0.000325
# INFO:DELFNO:Epoch  500/500: loss=0.000325
# 00:40:37 | INFO |   Result: test_err=0.000759, train_err=0.000515, time=498.3s
# INFO:DELFNO:  Result: test_err=0.000759, train_err=0.000515, time=498.3s
# 00:40:37 | INFO | Running: FNO, modes=16, seed=888
# INFO:DELFNO:Running: FNO, modes=16, seed=888
# 00:42:16 | INFO | Epoch  100/500: loss=0.025433
# INFO:DELFNO:Epoch  100/500: loss=0.025433
# 00:43:55 | INFO | Epoch  200/500: loss=0.010580
# INFO:DELFNO:Epoch  200/500: loss=0.010580
# 00:45:34 | INFO | Epoch  300/500: loss=0.004750
# INFO:DELFNO:Epoch  300/500: loss=0.004750
# 00:47:13 | INFO | Epoch  400/500: loss=0.001337
# INFO:DELFNO:Epoch  400/500: loss=0.001337
# 00:48:52 | INFO | Epoch  500/500: loss=0.000304
# INFO:DELFNO:Epoch  500/500: loss=0.000304
# 00:48:52 | INFO |   Result: test_err=0.000744, train_err=0.000447, time=494.7s
# INFO:DELFNO:  Result: test_err=0.000744, train_err=0.000447, time=494.7s
# 00:48:52 | INFO | Running: DEL-FNO, modes=16, seed=42
# INFO:DELFNO:Running: DEL-FNO, modes=16, seed=42
# 00:51:26 | INFO | Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.020053, β=[1.1881, 2.3165], scale=[0.0878, 0.0000]
# 00:53:59 | INFO | Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011274, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 00:56:33 | INFO | Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.006377, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 00:59:06 | INFO | Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001264, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 01:01:40 | INFO | Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000317, β=[1.2886, 2.3165], scale=[0.0000, 0.0000]
# 01:01:40 | INFO |   Result: test_err=0.000676, train_err=0.000436, time=767.5s
# INFO:DELFNO:  Result: test_err=0.000676, train_err=0.000436, time=767.5s
# 01:01:40 | INFO |   Final β: [1.288582444190979, 2.3165488243103027]
# INFO:DELFNO:  Final β: [1.288582444190979, 2.3165488243103027]
# 01:01:40 | INFO | Running: DEL-FNO, modes=16, seed=108
# INFO:DELFNO:Running: DEL-FNO, modes=16, seed=108
# 01:04:13 | INFO | Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# INFO:DELFNO:Epoch  100/500: loss=0.023876, β=[1.5586, 2.0074], scale=[0.4219, 0.1869]
# 01:06:47 | INFO | Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011716, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 01:09:20 | INFO | Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004751, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 01:11:54 | INFO | Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001192, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 01:14:28 | INFO | Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000311, β=[1.9527, 1.9375], scale=[0.0000, 0.0000]
# 01:14:28 | INFO |   Result: test_err=0.000741, train_err=0.000509, time=768.3s
# INFO:DELFNO:  Result: test_err=0.000741, train_err=0.000509, time=768.3s
# 01:14:28 | INFO |   Final β: [1.9527373313903809, 1.9374629259109497]
# INFO:DELFNO:  Final β: [1.9527373313903809, 1.9374629259109497]
# 01:14:28 | INFO | Running: DEL-FNO, modes=16, seed=888
# INFO:DELFNO:Running: DEL-FNO, modes=16, seed=888
# 01:17:02 | INFO | Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# INFO:DELFNO:Epoch  100/500: loss=0.023649, β=[1.3408, 2.0651], scale=[0.1161, 0.0299]
# 01:19:36 | INFO | Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012260, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 01:22:10 | INFO | Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005607, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 01:24:44 | INFO | Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001487, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 01:27:17 | INFO | Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000313, β=[1.3420, 2.0446], scale=[0.0000, 0.0000]
# 01:27:18 | INFO |   Result: test_err=0.000629, train_err=0.000409, time=769.3s
# INFO:DELFNO:  Result: test_err=0.000629, train_err=0.000409, time=769.3s
# 01:27:18 | INFO |   Final β: [1.3419767618179321, 2.044556140899658]
# INFO:DELFNO:  Final β: [1.3419767618179321, 2.044556140899658]
# 01:27:18 | INFO | Running: FNO, modes=32, seed=42
# INFO:DELFNO:Running: FNO, modes=32, seed=42
# 01:28:57 | INFO | Epoch  100/500: loss=0.025582
# INFO:DELFNO:Epoch  100/500: loss=0.025582
# 01:30:36 | INFO | Epoch  200/500: loss=0.012910
# INFO:DELFNO:Epoch  200/500: loss=0.012910
# 01:32:15 | INFO | Epoch  300/500: loss=0.005917
# INFO:DELFNO:Epoch  300/500: loss=0.005917
# 01:33:54 | INFO | Epoch  400/500: loss=0.001288
# INFO:DELFNO:Epoch  400/500: loss=0.001288
# 01:35:33 | INFO | Epoch  500/500: loss=0.000297
# INFO:DELFNO:Epoch  500/500: loss=0.000297
# 01:35:33 | INFO |   Result: test_err=0.000844, train_err=0.000541, time=495.5s
# INFO:DELFNO:  Result: test_err=0.000844, train_err=0.000541, time=495.5s
# 01:35:33 | INFO | Running: FNO, modes=32, seed=108
# INFO:DELFNO:Running: FNO, modes=32, seed=108
# 01:37:12 | INFO | Epoch  100/500: loss=0.018533
# INFO:DELFNO:Epoch  100/500: loss=0.018533
# 01:38:51 | INFO | Epoch  200/500: loss=0.009638
# INFO:DELFNO:Epoch  200/500: loss=0.009638
# 01:40:31 | INFO | Epoch  300/500: loss=0.004918
# INFO:DELFNO:Epoch  300/500: loss=0.004918
# 01:42:10 | INFO | Epoch  400/500: loss=0.001227
# INFO:DELFNO:Epoch  400/500: loss=0.001227
# 01:43:49 | INFO | Epoch  500/500: loss=0.000311
# INFO:DELFNO:Epoch  500/500: loss=0.000311
# 01:43:49 | INFO |   Result: test_err=0.000727, train_err=0.000444, time=496.3s
# INFO:DELFNO:  Result: test_err=0.000727, train_err=0.000444, time=496.3s
# 01:43:49 | INFO | Running: FNO, modes=32, seed=888
# INFO:DELFNO:Running: FNO, modes=32, seed=888
# 01:45:29 | INFO | Epoch  100/500: loss=0.016798
# INFO:DELFNO:Epoch  100/500: loss=0.016798
# 01:47:08 | INFO | Epoch  200/500: loss=0.011571
# INFO:DELFNO:Epoch  200/500: loss=0.011571
# 01:48:47 | INFO | Epoch  300/500: loss=0.005161
# INFO:DELFNO:Epoch  300/500: loss=0.005161
# 01:50:26 | INFO | Epoch  400/500: loss=0.001280
# INFO:DELFNO:Epoch  400/500: loss=0.001280
# 01:52:06 | INFO | Epoch  500/500: loss=0.000321
# INFO:DELFNO:Epoch  500/500: loss=0.000321
# 01:52:06 | INFO |   Result: test_err=0.000801, train_err=0.000526, time=496.2s
# INFO:DELFNO:  Result: test_err=0.000801, train_err=0.000526, time=496.2s
# 01:52:06 | INFO | Running: DEL-FNO, modes=32, seed=42
# INFO:DELFNO:Running: DEL-FNO, modes=32, seed=42
# 01:54:39 | INFO | Epoch  100/500: loss=0.022859, β=[0.9078, 1.9416], scale=[0.1836, 0.2024]
# INFO:DELFNO:Epoch  100/500: loss=0.022859, β=[0.9078, 1.9416], scale=[0.1836, 0.2024]
# 01:57:13 | INFO | Epoch  200/500: loss=0.013367, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.013367, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# 01:59:47 | INFO | Epoch  300/500: loss=0.004682, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004682, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# 02:02:22 | INFO | Epoch  400/500: loss=0.001398, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001398, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# 02:04:55 | INFO | Epoch  500/500: loss=0.000330, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000330, β=[1.1481, 2.0638], scale=[0.0000, 0.0000]
# 02:04:56 | INFO |   Result: test_err=0.000744, train_err=0.000476, time=769.8s
# INFO:DELFNO:  Result: test_err=0.000744, train_err=0.000476, time=769.8s
# 02:04:56 | INFO |   Final β: [1.1480740308761597, 2.063847541809082]
# INFO:DELFNO:  Final β: [1.1480740308761597, 2.063847541809082]
# 02:04:56 | INFO | Running: DEL-FNO, modes=32, seed=108
# INFO:DELFNO:Running: DEL-FNO, modes=32, seed=108
# 02:07:29 | INFO | Epoch  100/500: loss=0.022908, β=[1.3802, 1.8843], scale=[0.2328, 0.3687]
# INFO:DELFNO:Epoch  100/500: loss=0.022908, β=[1.3802, 1.8843], scale=[0.2328, 0.3687]
# 02:10:03 | INFO | Epoch  200/500: loss=0.009820, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.009820, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# 02:12:37 | INFO | Epoch  300/500: loss=0.005505, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005505, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# 02:15:11 | INFO | Epoch  400/500: loss=0.001383, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001383, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# 02:17:44 | INFO | Epoch  500/500: loss=0.000321, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000321, β=[1.3748, 1.8234], scale=[0.0000, 0.0000]
# 02:17:44 | INFO |   Result: test_err=0.000768, train_err=0.000443, time=768.9s
# INFO:DELFNO:  Result: test_err=0.000768, train_err=0.000443, time=768.9s
# 02:17:44 | INFO |   Final β: [1.3748029470443726, 1.8234314918518066]
# INFO:DELFNO:  Final β: [1.3748029470443726, 1.8234314918518066]
# 02:17:44 | INFO | Running: DEL-FNO, modes=32, seed=888
# INFO:DELFNO:Running: DEL-FNO, modes=32, seed=888
# 02:20:19 | INFO | Epoch  100/500: loss=0.023337, β=[1.4038, 2.0558], scale=[0.1939, 0.3176]
# INFO:DELFNO:Epoch  100/500: loss=0.023337, β=[1.4038, 2.0558], scale=[0.1939, 0.3176]
# 02:22:52 | INFO | Epoch  200/500: loss=0.011975, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011975, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# 02:25:27 | INFO | Epoch  300/500: loss=0.005431, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005431, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# 02:28:02 | INFO | Epoch  400/500: loss=0.001171, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001171, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# 02:30:36 | INFO | Epoch  500/500: loss=0.000324, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000324, β=[1.3990, 2.0600], scale=[0.0000, 0.0000]
# 02:30:36 | INFO |   Result: test_err=0.000809, train_err=0.000539, time=771.6s
# INFO:DELFNO:  Result: test_err=0.000809, train_err=0.000539, time=771.6s
# 02:30:36 | INFO |   Final β: [1.3990317583084106, 2.0600101947784424]
# INFO:DELFNO:  Final β: [1.3990317583084106, 2.0600101947784424]
# 02:30:36 | INFO | Running: FNO, modes=64, seed=42
# INFO:DELFNO:Running: FNO, modes=64, seed=42
# 02:32:16 | INFO | Epoch  100/500: loss=0.023444
# INFO:DELFNO:Epoch  100/500: loss=0.023444
# 02:33:55 | INFO | Epoch  200/500: loss=0.010722
# INFO:DELFNO:Epoch  200/500: loss=0.010722
# 02:35:33 | INFO | Epoch  300/500: loss=0.003870
# INFO:DELFNO:Epoch  300/500: loss=0.003870
# 02:37:12 | INFO | Epoch  400/500: loss=0.001391
# INFO:DELFNO:Epoch  400/500: loss=0.001391
# 02:38:51 | INFO | Epoch  500/500: loss=0.000303
# INFO:DELFNO:Epoch  500/500: loss=0.000303
# 02:38:51 | INFO |   Result: test_err=0.000806, train_err=0.000561, time=495.2s
# INFO:DELFNO:  Result: test_err=0.000806, train_err=0.000561, time=495.2s
# 02:38:51 | INFO | Running: FNO, modes=64, seed=108
# INFO:DELFNO:Running: FNO, modes=64, seed=108
# 02:40:30 | INFO | Epoch  100/500: loss=0.023754
# INFO:DELFNO:Epoch  100/500: loss=0.023754
# 02:42:10 | INFO | Epoch  200/500: loss=0.010638
# INFO:DELFNO:Epoch  200/500: loss=0.010638
# 02:43:49 | INFO | Epoch  300/500: loss=0.006204
# INFO:DELFNO:Epoch  300/500: loss=0.006204
# 02:45:29 | INFO | Epoch  400/500: loss=0.001012
# INFO:DELFNO:Epoch  400/500: loss=0.001012
# 02:47:08 | INFO | Epoch  500/500: loss=0.000292
# INFO:DELFNO:Epoch  500/500: loss=0.000292
# 02:47:08 | INFO |   Result: test_err=0.000760, train_err=0.000507, time=496.4s
# INFO:DELFNO:  Result: test_err=0.000760, train_err=0.000507, time=496.4s
# 02:47:08 | INFO | Running: FNO, modes=64, seed=888
# INFO:DELFNO:Running: FNO, modes=64, seed=888
# 02:48:47 | INFO | Epoch  100/500: loss=0.025100
# INFO:DELFNO:Epoch  100/500: loss=0.025100
# 02:50:26 | INFO | Epoch  200/500: loss=0.011012
# INFO:DELFNO:Epoch  200/500: loss=0.011012
# 02:52:05 | INFO | Epoch  300/500: loss=0.005133
# INFO:DELFNO:Epoch  300/500: loss=0.005133
# 02:53:44 | INFO | Epoch  400/500: loss=0.001267
# INFO:DELFNO:Epoch  400/500: loss=0.001267
# 02:55:23 | INFO | Epoch  500/500: loss=0.000309
# INFO:DELFNO:Epoch  500/500: loss=0.000309
# 02:55:23 | INFO |   Result: test_err=0.000765, train_err=0.000497, time=494.9s
# INFO:DELFNO:  Result: test_err=0.000765, train_err=0.000497, time=494.9s
# 02:55:23 | INFO | Running: DEL-FNO, modes=64, seed=42
# INFO:DELFNO:Running: DEL-FNO, modes=64, seed=42
# 02:57:56 | INFO | Epoch  100/500: loss=0.025136, β=[0.9694, 2.5796], scale=[0.1741, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.025136, β=[0.9694, 2.5796], scale=[0.1741, 0.0000]
# 03:00:30 | INFO | Epoch  200/500: loss=0.010162, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.010162, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# 03:03:04 | INFO | Epoch  300/500: loss=0.004196, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004196, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# 03:05:38 | INFO | Epoch  400/500: loss=0.001272, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001272, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# 03:08:12 | INFO | Epoch  500/500: loss=0.000289, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000289, β=[1.1119, 2.5796], scale=[0.0000, 0.0000]
# 03:08:12 | INFO |   Result: test_err=0.000748, train_err=0.000484, time=769.6s
# INFO:DELFNO:  Result: test_err=0.000748, train_err=0.000484, time=769.6s
# 03:08:12 | INFO |   Final β: [1.1118943691253662, 2.579594850540161]
# INFO:DELFNO:  Final β: [1.1118943691253662, 2.579594850540161]
# 03:08:12 | INFO | Running: DEL-FNO, modes=64, seed=108
# INFO:DELFNO:Running: DEL-FNO, modes=64, seed=108
# 03:10:46 | INFO | Epoch  100/500: loss=0.019530, β=[1.4771, 1.5139], scale=[0.1801, 0.5046]
# INFO:DELFNO:Epoch  100/500: loss=0.019530, β=[1.4771, 1.5139], scale=[0.1801, 0.5046]
# 03:13:21 | INFO | Epoch  200/500: loss=0.012272, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012272, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# 03:15:55 | INFO | Epoch  300/500: loss=0.005724, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005724, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# 03:18:29 | INFO | Epoch  400/500: loss=0.001204, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001204, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# 03:21:03 | INFO | Epoch  500/500: loss=0.000304, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000304, β=[1.4746, 1.5090], scale=[0.0000, 0.0000]
# 03:21:03 | INFO |   Result: test_err=0.000759, train_err=0.000503, time=770.3s
# INFO:DELFNO:  Result: test_err=0.000759, train_err=0.000503, time=770.3s
# 03:21:03 | INFO |   Final β: [1.474629282951355, 1.5089991092681885]
# INFO:DELFNO:  Final β: [1.474629282951355, 1.5089991092681885]
# 03:21:03 | INFO | Running: DEL-FNO, modes=64, seed=888
# INFO:DELFNO:Running: DEL-FNO, modes=64, seed=888
# 03:23:37 | INFO | Epoch  100/500: loss=0.017108, β=[1.2367, 1.9821], scale=[0.2704, 0.6579]
# INFO:DELFNO:Epoch  100/500: loss=0.017108, β=[1.2367, 1.9821], scale=[0.2704, 0.6579]
# 03:26:10 | INFO | Epoch  200/500: loss=0.011724, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.011724, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# 03:28:44 | INFO | Epoch  300/500: loss=0.005473, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005473, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# 03:31:17 | INFO | Epoch  400/500: loss=0.001529, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001529, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# 03:33:52 | INFO | Epoch  500/500: loss=0.000308, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000308, β=[1.2288, 2.0934], scale=[0.0000, 0.0000]
# 03:33:52 | INFO |   Result: test_err=0.000653, train_err=0.000405, time=768.6s
# INFO:DELFNO:  Result: test_err=0.000653, train_err=0.000405, time=768.6s
# 03:33:52 | INFO |   Final β: [1.2287778854370117, 2.0933690071105957]
# INFO:DELFNO:  Final β: [1.2287778854370117, 2.0933690071105957]
# 03:33:52 | INFO | Running: FNO, modes=128, seed=42
# INFO:DELFNO:Running: FNO, modes=128, seed=42
# 03:35:30 | INFO | Epoch  100/500: loss=0.019066
# INFO:DELFNO:Epoch  100/500: loss=0.019066
# 03:37:09 | INFO | Epoch  200/500: loss=0.012935
# INFO:DELFNO:Epoch  200/500: loss=0.012935
# 03:38:48 | INFO | Epoch  300/500: loss=0.005294
# INFO:DELFNO:Epoch  300/500: loss=0.005294
# 03:40:27 | INFO | Epoch  400/500: loss=0.001484
# INFO:DELFNO:Epoch  400/500: loss=0.001484
# 03:42:06 | INFO | Epoch  500/500: loss=0.000300
# INFO:DELFNO:Epoch  500/500: loss=0.000300
# 03:42:06 | INFO |   Result: test_err=0.000769, train_err=0.000472, time=494.7s
# INFO:DELFNO:  Result: test_err=0.000769, train_err=0.000472, time=494.7s
# 03:42:06 | INFO | Running: FNO, modes=128, seed=108
# INFO:DELFNO:Running: FNO, modes=128, seed=108
# 03:43:45 | INFO | Epoch  100/500: loss=0.024147
# INFO:DELFNO:Epoch  100/500: loss=0.024147
# 03:45:25 | INFO | Epoch  200/500: loss=0.011899
# INFO:DELFNO:Epoch  200/500: loss=0.011899
# 03:47:03 | INFO | Epoch  300/500: loss=0.004202
# INFO:DELFNO:Epoch  300/500: loss=0.004202
# 03:48:42 | INFO | Epoch  400/500: loss=0.001416
# INFO:DELFNO:Epoch  400/500: loss=0.001416
# 03:50:22 | INFO | Epoch  500/500: loss=0.000308
# INFO:DELFNO:Epoch  500/500: loss=0.000308
# 03:50:22 | INFO |   Result: test_err=0.000627, train_err=0.000375, time=495.1s
# INFO:DELFNO:  Result: test_err=0.000627, train_err=0.000375, time=495.1s
# 03:50:22 | INFO | Running: FNO, modes=128, seed=888
# INFO:DELFNO:Running: FNO, modes=128, seed=888
# 03:52:01 | INFO | Epoch  100/500: loss=0.019634
# INFO:DELFNO:Epoch  100/500: loss=0.019634
# 03:53:40 | INFO | Epoch  200/500: loss=0.010558
# INFO:DELFNO:Epoch  200/500: loss=0.010558
# 03:55:19 | INFO | Epoch  300/500: loss=0.004595
# INFO:DELFNO:Epoch  300/500: loss=0.004595
# 03:56:58 | INFO | Epoch  400/500: loss=0.001324
# INFO:DELFNO:Epoch  400/500: loss=0.001324
# 03:58:37 | INFO | Epoch  500/500: loss=0.000313
# INFO:DELFNO:Epoch  500/500: loss=0.000313
# 03:58:37 | INFO |   Result: test_err=0.000773, train_err=0.000522, time=495.3s
# INFO:DELFNO:  Result: test_err=0.000773, train_err=0.000522, time=495.3s
# 03:58:37 | INFO | Running: DEL-FNO, modes=128, seed=42
# INFO:DELFNO:Running: DEL-FNO, modes=128, seed=42
# 04:01:11 | INFO | Epoch  100/500: loss=0.022849, β=[0.9780, 1.3769], scale=[0.1660, 0.0000]
# INFO:DELFNO:Epoch  100/500: loss=0.022849, β=[0.9780, 1.3769], scale=[0.1660, 0.0000]
# 04:03:45 | INFO | Epoch  200/500: loss=0.012584, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012584, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# 04:06:19 | INFO | Epoch  300/500: loss=0.004296, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.004296, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# 04:08:53 | INFO | Epoch  400/500: loss=0.001934, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001934, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# 04:11:27 | INFO | Epoch  500/500: loss=0.000343, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000343, β=[1.0980, 1.3769], scale=[0.0000, 0.0000]
# 04:11:27 | INFO |   Result: test_err=0.000792, train_err=0.000507, time=770.1s
# INFO:DELFNO:  Result: test_err=0.000792, train_err=0.000507, time=770.1s
# 04:11:27 | INFO |   Final β: [1.0979604721069336, 1.3769227266311646]
# INFO:DELFNO:  Final β: [1.0979604721069336, 1.3769227266311646]
# 04:11:27 | INFO | Running: DEL-FNO, modes=128, seed=108
# INFO:DELFNO:Running: DEL-FNO, modes=128, seed=108
# 04:14:01 | INFO | Epoch  100/500: loss=0.018766, β=[1.2511, 1.5408], scale=[0.3942, 1.0552]
# INFO:DELFNO:Epoch  100/500: loss=0.018766, β=[1.2511, 1.5408], scale=[0.3942, 1.0552]
# 04:16:35 | INFO | Epoch  200/500: loss=0.009103, β=[1.2803, 1.5630], scale=[0.0000, 0.4870]
# INFO:DELFNO:Epoch  200/500: loss=0.009103, β=[1.2803, 1.5630], scale=[0.0000, 0.4870]
# 04:19:09 | INFO | Epoch  300/500: loss=0.004786, β=[1.2803, 1.6009], scale=[0.0000, 0.3124]
# INFO:DELFNO:Epoch  300/500: loss=0.004786, β=[1.2803, 1.6009], scale=[0.0000, 0.3124]
# 04:21:43 | INFO | Epoch  400/500: loss=0.001134, β=[1.2803, 1.5559], scale=[0.0000, 0.2015]
# INFO:DELFNO:Epoch  400/500: loss=0.001134, β=[1.2803, 1.5559], scale=[0.0000, 0.2015]
# 04:24:17 | INFO | Epoch  500/500: loss=0.000313, β=[1.2803, 1.5400], scale=[0.0000, 0.1794]
# INFO:DELFNO:Epoch  500/500: loss=0.000313, β=[1.2803, 1.5400], scale=[0.0000, 0.1794]
# 04:24:17 | INFO |   Result: test_err=0.000754, train_err=0.000499, time=769.8s
# INFO:DELFNO:  Result: test_err=0.000754, train_err=0.000499, time=769.8s
# 04:24:17 | INFO |   Final β: [1.2802528142929077, 1.53998601436615]
# INFO:DELFNO:  Final β: [1.2802528142929077, 1.53998601436615]
# 04:24:17 | INFO | Running: DEL-FNO, modes=128, seed=888
# INFO:DELFNO:Running: DEL-FNO, modes=128, seed=888
# 04:26:51 | INFO | Epoch  100/500: loss=0.020023, β=[1.2246, 1.8614], scale=[0.3786, 0.4062]
# INFO:DELFNO:Epoch  100/500: loss=0.020023, β=[1.2246, 1.8614], scale=[0.3786, 0.4062]
# 04:29:25 | INFO | Epoch  200/500: loss=0.012325, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  200/500: loss=0.012325, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# 04:31:59 | INFO | Epoch  300/500: loss=0.005733, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  300/500: loss=0.005733, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# 04:34:33 | INFO | Epoch  400/500: loss=0.001101, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  400/500: loss=0.001101, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# 04:37:07 | INFO | Epoch  500/500: loss=0.000324, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# INFO:DELFNO:Epoch  500/500: loss=0.000324, β=[1.1833, 2.0683], scale=[0.0000, 0.0000]
# 04:37:07 | INFO |   Result: test_err=0.000782, train_err=0.000495, time=770.3s
# INFO:DELFNO:  Result: test_err=0.000782, train_err=0.000495, time=770.3s
# 04:37:07 | INFO |   Final β: [1.1832813024520874, 2.06829833984375]
# INFO:DELFNO:  Final β: [1.1832813024520874, 2.06829833984375]
# 04:37:08 | INFO | Results saved to ./results/exp3_modes_scaling_r10.csv
# INFO:DELFNO:Results saved to ./results/exp3_modes_scaling_r10.csv
# 04:37:08 | INFO | Experiment 3 complete! Shape: (24, 14)
# INFO:DELFNO:Experiment 3 complete! Shape: (24, 14)

# %%
# @title Cell 14: Analysis Functions
# ═══════════════════════════════════════════════════════════════════
#                    ANALYSIS AND VISUALIZATION
# ═══════════════════════════════════════════════════════════════════

def analyze_results(df: pd.DataFrame, var_col: str, var_values: List,
                    cfg: Config, exp_name: str, xlabel: str):
    """Analyze and plot experiment results."""

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    summary = df.groupby([var_col, 'model'])['test_error'].agg(['mean', 'std']).reset_index()

    # Plot 1: Error vs variable
    ax = axes[0]
    for model in cfg.models:
        data = summary[summary['model'] == model]
        ax.errorbar(data[var_col], data['mean'], yerr=data['std'],
                   marker='o', capsize=4, label=model, linewidth=2, markersize=8)
    ax.set_xlabel(xlabel)
    ax.set_ylabel('Relative L2 Error')
    ax.set_title(f'Burgers {cfg.dataset.upper()}')
    ax.legend()
    ax.grid(True, alpha=0.3)
    ax.set_yscale('log')
    if var_col in ['n_train', 'modes']:
        ax.set_xscale('log', base=2)

    # Plot 2: Improvement %
    ax = axes[1]
    fno_errors = summary[summary['model'] == 'FNO'].set_index(var_col)['mean']
    del_errors = summary[summary['model'] == 'DEL-FNO'].set_index(var_col)['mean']
    improvement = (fno_errors - del_errors) / fno_errors * 100

    colors = ['green' if x > 0 else 'red' for x in improvement.values]
    ax.bar(range(len(improvement)), improvement.values, color=colors, alpha=0.7, edgecolor='black')
    ax.set_xticks(range(len(improvement)))
    ax.set_xticklabels([str(x) for x in improvement.index])
    ax.set_xlabel(xlabel)
    ax.set_ylabel('Improvement (%)')
    ax.set_title(f'{cfg.dataset.upper()}: DEL-FNO Improvement')
    ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5)
    ax.grid(True, alpha=0.3, axis='y')

    # Plot 3: Learned β values
    ax = axes[2]
    df_del = df[df['model'] == 'DEL-FNO']
    for i in range(cfg.nb_beta):
        beta_by_var = df_del.groupby(var_col).apply(
            lambda x: np.mean([b[i] for b in x['beta_values'] if b is not None])
        )
        marker = 'o' if i == 0 else 's'
        ax.plot(beta_by_var.index, beta_by_var.values, f'{marker}-',
               label=f'β{i+1}', markersize=8)
    ax.set_xlabel(xlabel)
    ax.set_ylabel('Learned β')
    ax.set_title('Learned Derivative Orders')
    ax.legend()
    ax.grid(True, alpha=0.3)
    if var_col in ['n_train', 'modes']:
        ax.set_xscale('log', base=2)

    plt.suptitle(f'{exp_name} - {cfg.dataset.upper()}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f"{cfg.results_dir}/{exp_name.lower().replace(' ', '_')}_{cfg.dataset}.png",
                dpi=150, bbox_inches='tight')
    plt.show()

    # Print summary table
    log.info(f"\n{exp_name} Summary:")
    log.info("-" * 70)
    log.info(f"{'Value':<12} {'FNO Error':<15} {'DEL-FNO Error':<15} {'Improvement':<12}")
    log.info("-" * 70)
    for val in var_values:
        df_v = df[df[var_col] == val]
        fno_err = df_v[df_v['model'] == 'FNO']['test_error'].mean()
        del_err = df_v[df_v['model'] == 'DEL-FNO']['test_error'].mean()
        imp = (fno_err - del_err) / fno_err * 100
        log.info(f"{str(val):<12} {fno_err:<15.6f} {del_err:<15.6f} {imp:+.1f}%")
    log.info("-" * 70)

# %%
# @title Cell 15: Analyze Noise Results
analyze_results(df_noise, 'noise_level', cfg.noise_levels, cfg,
                'Experiment 1: Noise Robustness', 'Noise Level (σ)')
# Out:
# 04:37:09 | INFO |
# Experiment 1: Noise Robustness Summary:
# INFO:DELFNO:
# Experiment 1: Noise Robustness Summary:
# 04:37:09 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:09 | INFO | Value        FNO Error       DEL-FNO Error   Improvement
# INFO:DELFNO:Value        FNO Error       DEL-FNO Error   Improvement
# 04:37:09 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:09 | INFO | 0.0          0.000785        0.000682        +13.1%
# INFO:DELFNO:0.0          0.000785        0.000682        +13.1%
# 04:37:09 | INFO | 0.01         0.000926        0.000806        +12.9%
# INFO:DELFNO:0.01         0.000926        0.000806        +12.9%
# 04:37:09 | INFO | 0.02         0.001313        0.001184        +9.8%
# INFO:DELFNO:0.02         0.001313        0.001184        +9.8%
# 04:37:09 | INFO | 0.05         0.003765        0.003385        +10.1%
# INFO:DELFNO:0.05         0.003765        0.003385        +10.1%
# 04:37:09 | INFO | 0.1          0.008832        0.006964        +21.1%
# INFO:DELFNO:0.1          0.008832        0.006964        +21.1%
# 04:37:09 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------

# %%
# @title Cell 16: Analyze Sample Efficiency Results
analyze_results(df_sample, 'n_train', cfg.sample_sizes, cfg,
                'Experiment 2: Sample Efficiency', 'Training Samples')
# Out:
# 04:37:10 | INFO |
# Experiment 2: Sample Efficiency Summary:
# INFO:DELFNO:
# Experiment 2: Sample Efficiency Summary:
# 04:37:10 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:10 | INFO | Value        FNO Error       DEL-FNO Error   Improvement
# INFO:DELFNO:Value        FNO Error       DEL-FNO Error   Improvement
# 04:37:10 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:10 | INFO | 125          0.003449        0.003508        -1.7%
# INFO:DELFNO:125          0.003449        0.003508        -1.7%
# 04:37:10 | INFO | 250          0.001555        0.001491        +4.1%
# INFO:DELFNO:250          0.001555        0.001491        +4.1%
# 04:37:10 | INFO | 500          0.001123        0.001041        +7.3%
# INFO:DELFNO:500          0.001123        0.001041        +7.3%
# 04:37:10 | INFO | 1000         0.000785        0.000682        +13.1%
# INFO:DELFNO:1000         0.000785        0.000682        +13.1%
# 04:37:10 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------

# %%
# @title Cell 17: Analyze Modes Results
analyze_results(df_modes, 'modes', cfg.modes_list, cfg,
                'Experiment 3: Modes Scaling', 'Fourier Modes')
# Out:
# 04:37:11 | INFO |
# Experiment 3: Modes Scaling Summary:
# INFO:DELFNO:
# Experiment 3: Modes Scaling Summary:
# 04:37:11 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:11 | INFO | Value        FNO Error       DEL-FNO Error   Improvement
# INFO:DELFNO:Value        FNO Error       DEL-FNO Error   Improvement
# 04:37:11 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------
# 04:37:11 | INFO | 16           0.000785        0.000682        +13.1%
# INFO:DELFNO:16           0.000785        0.000682        +13.1%
# 04:37:11 | INFO | 32           0.000791        0.000774        +2.2%
# INFO:DELFNO:32           0.000791        0.000774        +2.2%
# 04:37:11 | INFO | 64           0.000777        0.000720        +7.3%
# INFO:DELFNO:64           0.000777        0.000720        +7.3%
# 04:37:11 | INFO | 128          0.000723        0.000776        -7.3%
# INFO:DELFNO:128          0.000723        0.000776        -7.3%
# 04:37:11 | INFO | ----------------------------------------------------------------------
# INFO:DELFNO:----------------------------------------------------------------------

# %%
# @title Cell 18: Summary Figure
def create_summary_figure(cfg: Config):
    """Create comprehensive summary of all experiments."""

    df_noise = pd.read_csv(f"{cfg.results_dir}/exp1_noise_robustness_{cfg.dataset}.csv")
    df_sample = pd.read_csv(f"{cfg.results_dir}/exp2_sample_efficiency_{cfg.dataset}.csv")
    df_modes = pd.read_csv(f"{cfg.results_dir}/exp3_modes_scaling_{cfg.dataset}.csv")

    fig, axes = plt.subplots(2, 3, figsize=(16, 10))

    experiments = [
        (df_noise, 'noise_level', 'Noise σ', cfg.noise_levels, 'linear'),
        (df_sample, 'n_train', 'Training Samples', cfg.sample_sizes, 'log'),
        (df_modes, 'modes', 'Fourier Modes', cfg.modes_list, 'log2'),
    ]

    # Row 1: Error curves
    for col, (df, var_col, xlabel, values, xscale) in enumerate(experiments):
        ax = axes[0, col]
        for model in cfg.models:
            df_m = df[df['model'] == model]
            err = df_m.groupby(var_col)['test_error'].mean()
            style = '-o' if model == 'FNO' else '--s'
            ax.plot(err.index, err.values, style, label=model, markersize=6)
        ax.set_xlabel(xlabel)
        ax.set_ylabel('Relative L2 Error')
        ax.set_title(f'Exp {col+1}')
        ax.legend(fontsize=8)
        ax.set_yscale('log')
        if xscale == 'log':
            ax.set_xscale('log')
        elif xscale == 'log2':
            ax.set_xscale('log', base=2)
        ax.grid(True, alpha=0.3)

    # Row 2: Improvement bars
    for col, (df, var_col, xlabel, values, _) in enumerate(experiments):
        ax = axes[1, col]
        imps = []
        for v in values:
            df_v = df[df[var_col] == v]
            fno = df_v[df_v['model'] == 'FNO']['test_error'].mean()
            del_fno = df_v[df_v['model'] == 'DEL-FNO']['test_error'].mean()
            imps.append((fno - del_fno) / fno * 100)

        colors = ['green' if x > 0 else 'red' for x in imps]
        ax.bar(range(len(values)), imps, color=colors, alpha=0.7, edgecolor='black')
        ax.set_xticks(range(len(values)))
        ax.set_xticklabels([str(v) for v in values], fontsize=8)
        ax.set_xlabel(xlabel)
        ax.set_ylabel('DEL-FNO Improvement (%)')
        ax.axhline(y=0, color='black', linewidth=0.5)
        ax.grid(True, alpha=0.3, axis='y')

    plt.suptitle(f'DEL-FNO Experiments Summary - Burgers {cfg.dataset.upper()}',
                 fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f"{cfg.results_dir}/summary_all_experiments_{cfg.dataset}.png",
                dpi=200, bbox_inches='tight')
    plt.show()

create_summary_figure(cfg)
